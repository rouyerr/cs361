# %%
import os
import glob
import json
import ndjson
import shutil
import requests

def load_json_from_api(url, header=None, params = None, fmt = None):
    response = requests.get(url, headers=header, params=params)
    print(url)
    if response.status_code == 200:
        
        #return response
        if fmt == None:
            json_data = response.json()
        else:
            json_data = response.json(cls=fmt)
        return json_data
    else:
        print(f"Error: Failed to retrieve data from the API. Status Code {response.status_code}")
        return None


def get_chess_com_games(username=None, time_formats=None):
    
    with open(f".\\config.json", "r") as f:
        config = json.load(f)
        
    if username==None:
        username = config.get("chess_com_user")
    if time_formats == None:
        time_formats = config.get("time_formats")
    imported_dir = config.get("imported_dir")
    header = {'User-Agent': config.get("email")}
    api_url = f"https://api.chess.com/pub/player/{username}/games/archives"
    monthlyURLS = load_json_from_api(api_url, header)
    if monthlyURLS is None:
        return None
    
    monthlyURLS = monthlyURLS.get("archives")
    
    games = []

    for url in monthlyURLS:
        month = load_json_from_api(url, header)
        games.extend(month.get("games"))
        print(len(games))
    games = list(filter(lambda g: g.get("rated") == True and g.get("time_format") in time_formats and g.get("initial_setup") == "rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1", games))
    for g in games:
        g["variant"] = "standard" if g.get("rules") == "chess" else g.get("rules")
        g["platform"] = "chess.com"
        g["player_color"] = "white" if g.get("white").get("username") == username else "black"
    

    
    with open(f".\\{imported_dir}\\games.json", "w") as f:
        json.dump(games,f)
    

    return games


def get_lichess_games(username=None, time_formats=None):
        
    with open(f".\\config.json", "r") as f:
        config = json.load(f)
        
    if username==None:
        username = config.get("lichess_user")
    if time_formats == None:
        time_formats = config.get("time_formats")
    imported_dir = config.get("imported_dir")
    header = {"Authorization": f"Bearer {config.get('lichess_token')}",
             "Accept": "application/x-ndjson"}

    if username==None:
        username = config.get('user')

    api_url = f"https://lichess.org/api/games/user/{username}"
    
    params = {
        "pgnInJson": True,
        
    }
    
    # params = {
    #     "since": since,
    #     "until": until,
    #     "max": max,
    #     "vs": vs,
    #     "rated": rated,
    #     "perfType": perf_type,
    #     "color": color,
    #     "analysed": analysed,
    #     "moves": moves,
    #     "pgnInJson": "true",
    #     "tags": tags,
    #     "clocks": clocks,
    #     "evals": evals,
    #     "opening": opening,
    #     "ongoing": ongoing,
    #     "finished": finished,
    #     "players": players,
    #     "sort": sort,
    #     "literate": literate,
    # }
    games = load_json_from_api(api_url,header=header, params = params, fmt = ndjson.Decoder)
    
    games = list(filter(lambda g: g.get("rated") == True and g.get("variant")== "standard" and g.get("perf") in time_formats, games))
    print(len(games))
    for g in games:
        g["end_time"] = g.get("lastMoveAt")
        g["time_class"] = g.get("speed")
        g["winner"] = g.get("winner", "draw")
        players = g.pop("players", None)
        
        g["white"] = players.get("white")
        g["white"]["username"] = g.get("white").pop("user", None).get("id")
        g["black"] = players.get("black")
        g["black"]["username"] = g.get("black").pop("user", None).get("id")
        g["platform"] = "lichess"
        g["player_color"] = "white" if g.get("white").get("username") == username else "black"
        

    white_games = list(filter(lambda g: g.get("player_color") == "white", games))
    black_games = list(filter(lambda g: g.get("player_color") == "black", games))
    
    with open(f".\\{imported_dir}\\lc_{username}_all_games.json", "w") as f:
        json.dump(games,f)
   

    return games

def import_pgn_file(file_path, username=None):
    
    with open(f".\\config.json", "r") as f:
        config = json.load(f)
    if username==None:
        username = config.get('name')
    imported_dir = config.get("imported_dir")
    with open(f".\\{file_path}{'.pgn' if not file_path.endswith('.pgn') else''}", "r") as f:
        lines = f.readlines()
    games = []
    g = None
    pgn=""
    tag_start_flag = True
    for line in lines:
        pgn+=f"{line}\n"
        if line.startswith("[Event"):
            if g!= None:
                g["pgn"]=pgn
                games.append(g)
                pgn=""
            g=dict()
            tag_start_flag = True
        if line[0] == "[":
            tag = line[1:].split('"')
            tag[0]=tag[0].lower()
            g[tag[0]] = tag[1]
            if (tag[0] == "white" or tag[0] == "black") and tag[1] == username:
                g["player_color"] = tag[0]
            
        elif line.startswith("1."):
            g["moves"]=f"{g.get('moves','')}{line}\n"
    if g!= None:
        g["pgn"]=pgn
        games.append(g)
        pgn=""
    file_name = file_path.split("\\")[-1]
    with open(f".\\{imported_dir}\\pgn_{file_name.split('.')[0]}_all_games.json", "w") as f:
        json.dump(games,f)
        
    return games

def ingest_pgns(pgn_files=None, username=None):
    with open(f".\\config.json", "r") as f:
        config = json.load(f)
    if pgn_files == None:
        pgn_files = config.get("ingest_dir")
    ingested_dir = config.get("ingested_dir", None)
    games = []
    if os.path.isdir(pgn_files):
        pgn_files = glob.glob(os.path.join(pgn_files, "*.pgn"))
        if not pgn_files:
            print(f"{pgn_files} is empty or contains no .pgn files")
        for pgn_file in pgn_files:
            print(f"Ingesting {pgn_file}")
            games.extend(import_pgn_file(pgn_file, username))
            print(f"Done ingesting {pgn_file}")
            if ingested_dir:
                if not os.path.exists(ingested_dir):
                    os.makedirs(ingested_dir)
                file_name = pgn_file.split('\\')[-1]
                move_file = f"{ingested_dir}\\{file_name}"
                print(f"Moving to {move_file}")
                shutil.move(pgn_file, ingested_dir)
        
        return games
    if os.path.isfile(pgn_files) and pgn_files.lower().endswith(".pgn"):
        return import_pgn_file(pgn_files)
    

def import_all_games(file_name=None, chess_com_user=None, lichess_user=None, pgns_files=None, time_formats = None):
    
    
    with open(f".\\config.json", "r") as f:
        config = json.load(f)
    imported_dir = config.get("imported_dir")
    if not os.path.exists(imported_dir):
        os.makedirs(imported_dir)
    if file_name == None:
        file_name = f"{config.get('name')}"
    if chess_com_user == None:
        chess_com_user = config.get("chess_com_user", False)
    if lichess_user == None:
        lichess_user = config.get("lichess_user", False)
    if pgns_files == None:
        pgns_files = config.get("ingest_dir", False)
    
    full_file_path = f"{imported_dir}\\{file_name}_all_games.json"
    if os.path.isfile(full_file_path):
        print(f"File {full_file_path} is already found so appending games")
        with open(full_file_path, "r") as f:
            games = json.load(f)
    else:
        games = []
    if chess_com_user:
        print(f"Ingesting Chess.com Games from user {chess_com_user}")
        #games.extend(get_chess_com_games(chess_com_user,time_formats))
    if lichess_user:
        print(f"Ingesting Lichess Games from user {lichess_user}")
        #games.extend(get_lichess_games(lichess_user,time_formats))
    if pgns_files:
        print(f"Ingesting Pgns files {pgns_files}")
        games.extend(ingest_pgns(pgns_files))  
    #print(games)
    white_games = []#list(filter(lambda g: g.get("player_color","") == "white", games))
    black_games = []#list(filter(lambda g: g.get("player_color","") == "black", games))
    
    with open(f".\\{imported_dir}\\{file_name}_all_games.json", "w") as f:
        json.dump(games,f)
    with open(f".\\{imported_dir}\\{file_name}_white_games.json", "w") as f:
        json.dump(white_games,f)
    with open(f".\\{imported_dir}\\{file_name}_black_games.json", "w") as f:
        json.dump(black_games,f)
    return games

# %%
# %%time
games = import_all_games()
# Out:
# File imported_pgns\Remy Rouyer_all_games.json is already found so appending games
# Ingesting Chess.com Games from user remyrouyer
# Ingesting Lichess Games from user remyrouyer
# Ingesting Pgns files ingest_pgns
# Ingesting ingest_pgns\chess_com_games_2021-10-17.pgn
# Done ingesting ingest_pgns\chess_com_games_2021-10-17.pgn
# Moving to ingested_pgns\chess_com_games_2021-10-17.pgn
# Ingesting ingest_pgns\lichess_study_urusov-gambit_by_remyrouyer_2020.11.21.pgn
# Done ingesting ingest_pgns\lichess_study_urusov-gambit_by_remyrouyer_2020.11.21.pgn
# Moving to ingested_pgns\lichess_study_urusov-gambit_by_remyrouyer_2020.11.21.pgn
# CPU times: total: 15.6 ms
# Wall time: 20.5 ms

# %%
games
# Out:
# [[{'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.15',
#    'round ': '-',
#    'white ': 'remyrouyer',
#    'black ': 'VJ100NIA',
#    'result ': '0-1',
#    'whiteelo ': '1662',
#    'blackelo ': '1687',
#    'timecontrol ': '600',
#    'endtime ': '23:18:25 PDT',
#    'termination ': 'VJ100NIA won by checkmate',
#    'moves': '1. e4 c5 2. c3 e6 3. d4 d5 4. e5 Nc6 5. Bb5 Qb6 6. Qa4 Bd7 7. Be3 a6 8. dxc5\n\n',
#    'pgn': '[Event "Live Chess"]\n\n[Site "Chess.com"]\n\n[Date "2021.10.15"]\n\n[Round "-"]\n\n[White "remyrouyer"]\n\n[Black "VJ100NIA"]\n\n[Result "0-1"]\n\n[WhiteElo "1662"]\n\n[BlackElo "1687"]\n\n[TimeControl "600"]\n\n[EndTime "23:18:25 PDT"]\n\n[Termination "VJ100NIA won by checkmate"]\n\n\n\n1. e4 c5 2. c3 e6 3. d4 d5 4. e5 Nc6 5. Bb5 Qb6 6. Qa4 Bd7 7. Be3 a6 8. dxc5\n\nQxb5 9. Qxb5 axb5 10. Ne2 Be7 11. Na3 Nxe5 12. O-O Nc4 13. Nxc4 bxc4 14. Nd4 Bc6\n\n15. Nxc6 bxc6 16. a4 Nf6 17. a5 O-O 18. a6 Rfb8 19. Bf4 Rxb2 20. a7 Nh5 21. Bb8\n\nRbxb8 22. axb8=Q+ Rxb8 23. Rfb1 Rxb1+ 24. Rxb1 h6 25. Rb7 Bxc5 26. Rc7 Bd6 27.\n\nRxc6 Be5 28. Kf1 Bxc3 29. Ke2 Nf4+ 30. Kf3 Bd2 31. g3 Ng6 32. Ke2 c3 33. Kd1 Ne7\n\n34. Rc7 Nf5 35. h4 g5 36. hxg5 hxg5 37. g4 Nd4 38. Rc8+ Kg7 39. Ra8 Nf3 40. Ra3\n\nNh2 41. Ra4 Kf6 42. Ke2 Ke5 43. f3 f5 44. gxf5 Kxf5 45. Ra1 d4 46. Rh1 Bf4 47.\n\nKd3 e5 48. Ke2 e4 49. fxe4+ Kxe4 50. Kd1 g4 51. Re1+ Be3 52. Rh1 g3 53. Ke2 d3+\n\n54. Kd1 c2+ 55. Ke1 c1=Q# 0-1\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.15',
#    'round ': '-',
#    'white ': 'remyrouyer',
#    'black ': 'zaela88',
#    'result ': '1-0',
#    'whiteelo ': '1670',
#    'blackelo ': '1662',
#    'timecontrol ': '600',
#    'endtime ': '23:49:54 PDT',
#    'termination ': 'remyrouyer won by resignation',
#    'moves': '1. e4 e6 2. d4 d6 3. c4 Bd7 4. Nc3 Nf6 5. Nf3 h6 6. b4 Bc6 7. Bd3 Be7 8. Qe2 b6\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.15"]\n\n[Round "-"]\n\n[White "remyrouyer"]\n\n[Black "zaela88"]\n\n[Result "1-0"]\n\n[WhiteElo "1670"]\n\n[BlackElo "1662"]\n\n[TimeControl "600"]\n\n[EndTime "23:49:54 PDT"]\n\n[Termination "remyrouyer won by resignation"]\n\n\n\n1. e4 e6 2. d4 d6 3. c4 Bd7 4. Nc3 Nf6 5. Nf3 h6 6. b4 Bc6 7. Bd3 Be7 8. Qe2 b6\n\n9. a4 Bb7 10. a5 Nbd7 11. a6 Bc8 12. e5 Nh5 13. Be4 Rb8 14. Bc6 dxe5 15. Nxe5\n\nNf6 16. Ne4 Bxb4+ 17. Bd2 Bxd2+ 18. Nxd2 O-O 19. Ne4 Nxe4 20. Qxe4 Nxe5 21. Qxe5\n\nQe7 22. O-O Bd7 23. Qxc7 Rbd8 24. d5 exd5 25. cxd5 Rfe8 26. d6 Qe6 27. h3 Bxc6\n\n28. Qxc6 Rxd6 29. Qb7 Qg6 30. Qxa7 Rd3 31. Kh2 Re2 32. Qb8+ Kh7 33. a7 Rxh3+ 34.\n\nKxh3 f5 35. Kh2 Qh5+ 36. Kg1 f4 37. Qxf4 Re8 38. a8=Q Rb8 39. Qaxb8 1-0\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'remyrouyer',
#    'black ': 'sourabhvadekar',
#    'result ': '1-0',
#    'whiteelo ': '1679',
#    'blackelo ': '1706',
#    'timecontrol ': '600',
#    'endtime ': '0:07:17 PDT',
#    'termination ': 'remyrouyer won by resignation',
#    'moves': '1. e4 c5 2. c3 e6 3. d4 cxd4 4. cxd4 d5 5. e5 Nc6 6. Bb5 Bd7 7. Nf3 Qa5+ 8. Nc3\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "remyrouyer"]\n\n[Black "sourabhvadekar"]\n\n[Result "1-0"]\n\n[WhiteElo "1679"]\n\n[BlackElo "1706"]\n\n[TimeControl "600"]\n\n[EndTime "0:07:17 PDT"]\n\n[Termination "remyrouyer won by resignation"]\n\n\n\n1. e4 c5 2. c3 e6 3. d4 cxd4 4. cxd4 d5 5. e5 Nc6 6. Bb5 Bd7 7. Nf3 Qa5+ 8. Nc3\n\nBb4 9. Bxc6 Bxc3+ 10. bxc3 Qxc3+ 11. Bd2 Qxc6 12. O-O Ne7 13. Bg5 Nf5 14. a4 O-O\n\n15. Nh4 Nxh4 16. Bxh4 Rfc8 17. Be7 a6 18. Qg4 Qc4 19. Bf6 g6 20. Qg5 Qb4 21. Be7\n\nQxd4 22. Rfd1 Qxe5 23. Qxe5 1-0\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'ihmisporsas',
#    'black ': 'remyrouyer',
#    'result ': '0-1',
#    'whiteelo ': '1689',
#    'blackelo ': '1688',
#    'timecontrol ': '600',
#    'endtime ': '2:11:42 PDT',
#    'termination ': 'remyrouyer won by resignation',
#    'moves': '1. b4 e5 2. Bb2 e4 3. e3 f5 4. Bc4 d5 5. Bb3 Nf6 6. a3 Nc6 7. Ne2 Be6 8. Nf4 Bf7\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "ihmisporsas"]\n\n[Black "remyrouyer"]\n\n[Result "0-1"]\n\n[WhiteElo "1689"]\n\n[BlackElo "1688"]\n\n[TimeControl "600"]\n\n[EndTime "2:11:42 PDT"]\n\n[Termination "remyrouyer won by resignation"]\n\n\n\n1. b4 e5 2. Bb2 e4 3. e3 f5 4. Bc4 d5 5. Bb3 Nf6 6. a3 Nc6 7. Ne2 Be6 8. Nf4 Bf7\n\n9. d3 Bd6 10. Nh3 Qe7 11. O-O O-O-O 12. b5 Na5 13. c4 dxc4 14. dxc4 Bxh2+ 15.\n\nKxh2 Rxd1 16. Bxd1 Nxc4 17. Bd4 Nb6 18. a4 Rd8 19. Bxb6 axb6 20. a5 bxa5 21.\n\nRxa5 Kb8 22. Nc3 Qb4 23. Ra4 Qxc3 24. Be2 Nd5 25. Bc4 Rf8 26. Rfa1 Nb6 27. R1a3\n\nNxa4 28. Rxc3 Nxc3 0-1\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'remyrouyer',
#    'black ': 'dDrB',
#    'result ': '1-0',
#    'whiteelo ': '1696',
#    'blackelo ': '1692',
#    'timecontrol ': '600',
#    'endtime ': '2:31:12 PDT',
#    'termination ': 'remyrouyer won on time',
#    'moves': '1. e4 g6 2. d4 Bg7 3. c4 c5 4. d5 Qb6 5. Nc3 d6 6. Nf3 Nf6 7. Bd3 Bg4 8. h3 Bxf3\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "remyrouyer"]\n\n[Black "dDrB"]\n\n[Result "1-0"]\n\n[WhiteElo "1696"]\n\n[BlackElo "1692"]\n\n[TimeControl "600"]\n\n[EndTime "2:31:12 PDT"]\n\n[Termination "remyrouyer won on time"]\n\n\n\n1. e4 g6 2. d4 Bg7 3. c4 c5 4. d5 Qb6 5. Nc3 d6 6. Nf3 Nf6 7. Bd3 Bg4 8. h3 Bxf3\n\n9. Qxf3 Nbd7 10. O-O Ne5 11. Qe2 Nxd3 12. Qxd3 h5 13. Bg5 Qxb2 14. Rfb1 Qa3 15.\n\nRb3 Qa5 16. Rxb7 O-O 17. Nb5 Nxe4 18. Rd1 Nxg5 19. Qe3 Bf6 20. h4 Nh7 21. Nc7\n\nRab8 22. Rdb1 Rxb7 23. Rxb7 Qxa2 24. Qh6 Qa1+ 25. Kh2 Be5+ 26. Kh3 Qc3+ 27. g3\n\nQe1 28. Kg2 Qe4+ 29. Kg1 Qxc4 30. Ne6 fxe6 31. Qxg6+ Kh8 32. Rxe7 Qc1+ 33. Kg2\n\nRxf2+ 34. Kxf2 Bd4+ 35. Ke2 Qe3+ 36. Kd1 Qg1+ 37. Kc2 Qf2+ 38. Kb3 Qb2+ 39. Kc4\n\nQb4+ 40. Kd3 Qb1+ 41. Kc4 Qxg6 42. Rxa7 Qc2+ 43. Kb5 Qb3+ 44. Kc6 c4 45. Ra8+\n\nKg7 46. dxe6 c3 47. Rd8 c2 48. Rd7+ Kf6 49. Kxd6 c1=Q 50. Rf7+ Kg6 51. Rc7 Qxc7+\n\n52. Kxc7 Qxe6 53. g4 Qb6+ 54. Kd7 Qc5 55. Ke6 Kg7 56. gxh5 Qe5+ 57. Kd7 Kf7 58.\n\nKc6 Qc5+ 59. Kd7 Nf6+ 60. Kd8 Qb6+ 61. Kc8 Qc6+ 62. Kb8 Be5+ 63. Ka7 Qc7+ 64.\n\nKa6 Qc6+ 65. Ka5 Bd4 66. Kb4 Bc3+ 67. Kb3 1-0\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'remyrouyer',
#    'black ': 'othello1200',
#    'result ': '0-1',
#    'whiteelo ': '1687',
#    'blackelo ': '1656',
#    'timecontrol ': '600',
#    'endtime ': '2:46:08 PDT',
#    'termination ': 'othello1200 won by resignation',
#    'moves': '1. e4 c5 2. c3 d6 3. d4 Nf6 4. e5 dxe5 5. Qa4+ Bd7 6. Bb5 cxd4 7. cxd4 exd4 8.\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "remyrouyer"]\n\n[Black "othello1200"]\n\n[Result "0-1"]\n\n[WhiteElo "1687"]\n\n[BlackElo "1656"]\n\n[TimeControl "600"]\n\n[EndTime "2:46:08 PDT"]\n\n[Termination "othello1200 won by resignation"]\n\n\n\n1. e4 c5 2. c3 d6 3. d4 Nf6 4. e5 dxe5 5. Qa4+ Bd7 6. Bb5 cxd4 7. cxd4 exd4 8.\n\nBg5 a6 9. Nf3 h6 10. Bxf6 exf6 11. Bxd7+ Qxd7 12. Qxd7+ Nxd7 13. O-O Bb4 14.\n\nNxd4 O-O 15. a3 Bc5 16. Nf3 Ne5 17. Nbd2 Rad8 18. b4 Ba7 19. Rad1 Rd3 20. Rfe1\n\nNxf3+ 21. Nxf3 Rxa3 22. Rd7 Rb8 23. Rb1 Ra2 24. Nd4 Bxd4 25. Rxd4 b5 26. Rd6 Rb7\n\n27. g3 a5 28. Ra6 a4 29. Kf1 Rd2 30. Ra5 Rd5 31. Ra1 Kh7 32. R1xa4 bxa4 33. Rxd5\n\nRxb4 34. Ra5 Kg6 35. Ke1 f5 36. Kd2 Kg5 37. Kc3 Re4 38. h4+ Kg6 39. Kd3 f6 40.\n\nf3 Rb4 41. Kc3 Rb3+ 42. Kd4 Rxf3 43. Rxa4 Rxg3 44. Kd5 Rg4 45. Rxg4+ fxg4 46.\n\nKe4 Kh5 47. Kf4 Kxh4 48. Ke3 Kg3 49. Ke2 Kg2 0-1\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'remyrouyer',
#    'black ': 'ZombieCheese',
#    'result ': '0-1',
#    'whiteelo ': '1680',
#    'blackelo ': '1736',
#    'timecontrol ': '600',
#    'endtime ': '2:55:55 PDT',
#    'termination ': 'ZombieCheese won by resignation',
#    'moves': '1. e4 c6 2. d4 d5 3. e5 c5 4. c3 Bf5 5. Bb5+ Nc6 6. Nf3 e6 7. O-O Qb6 8. Qa4 Rc8\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "remyrouyer"]\n\n[Black "ZombieCheese"]\n\n[Result "0-1"]\n\n[WhiteElo "1680"]\n\n[BlackElo "1736"]\n\n[TimeControl "600"]\n\n[EndTime "2:55:55 PDT"]\n\n[Termination "ZombieCheese won by resignation"]\n\n\n\n1. e4 c6 2. d4 d5 3. e5 c5 4. c3 Bf5 5. Bb5+ Nc6 6. Nf3 e6 7. O-O Qb6 8. Qa4 Rc8\n\n9. Na3 a6 10. Bxc6+ bxc6 11. Nh4 Bd3 12. Rd1 Bb5 13. Nxb5 cxb5 14. Qc2 cxd4 15.\n\nQd2 dxc3 16. bxc3 Bc5 17. Rb1 Nh6 18. c4 Ng4 19. cxd5 Nxf2 20. Qe2 Nxd1+ 21. Kh1\n\nNf2+ 22. Kg1 Nd3+ 23. Kh1 Nxc1 24. Rxc1 exd5 25. Nf5 O-O 26. Qg4 Qg6 27. Ne7+\n\nBxe7 28. Rxc8 Qxg4 29. Rxf8+ Kxf8 0-1\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'PossiblyRainz',
#    'black ': 'remyrouyer',
#    'result ': '0-1',
#    'whiteelo ': '1661',
#    'blackelo ': '1688',
#    'timecontrol ': '600',
#    'endtime ': '14:29:07 PDT',
#    'termination ': 'remyrouyer won by resignation',
#    'moves': '1. a4 e5 2. Nc3 d5 3. e4 d4 4. Nce2 c5 5. d3 Nc6 6. f4 f6 7. Nf3 Bg4 8. Ng3 h5\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "PossiblyRainz"]\n\n[Black "remyrouyer"]\n\n[Result "0-1"]\n\n[WhiteElo "1661"]\n\n[BlackElo "1688"]\n\n[TimeControl "600"]\n\n[EndTime "14:29:07 PDT"]\n\n[Termination "remyrouyer won by resignation"]\n\n\n\n1. a4 e5 2. Nc3 d5 3. e4 d4 4. Nce2 c5 5. d3 Nc6 6. f4 f6 7. Nf3 Bg4 8. Ng3 h5\n\n9. h3 Bxf3 10. Qxf3 h4 11. Ne2 Nb4 12. Kd1 Nc6 13. fxe5 Nxe5 14. Qf2 Bd6 15. Bf4\n\nQc7 16. Bh2 Nxd3 17. cxd3 Bxh2 18. g3 Bxg3 19. Nxg3 hxg3 20. Qf3 O-O-O 21. Bg2\n\nNe7 22. Kc2 c4 23. Rac1 cxd3+ 24. Kxd3 Nc6 25. e5 Nxe5+ 26. Ke2 Nxf3 27. Rxc7+\n\nKxc7 28. Rc1+ Kb8 29. Bxf3 d3+ 30. Kd2 Rxh3 31. Rg1 0-1\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'Mattster756',
#    'black ': 'remyrouyer',
#    'result ': '1-0',
#    'whiteelo ': '1740',
#    'blackelo ': '1681',
#    'timecontrol ': '600',
#    'endtime ': '14:49:36 PDT',
#    'termination ': 'Mattster756 won by checkmate',
#    'moves': '1. e4 e5 2. Nc3 Nf6 3. f4 d5 4. fxe5 Nxe4 5. Qf3 Nxc3 6. bxc3 Bc5 7. d4 Bb6 8.\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "Mattster756"]\n\n[Black "remyrouyer"]\n\n[Result "1-0"]\n\n[WhiteElo "1740"]\n\n[BlackElo "1681"]\n\n[TimeControl "600"]\n\n[EndTime "14:49:36 PDT"]\n\n[Termination "Mattster756 won by checkmate"]\n\n\n\n1. e4 e5 2. Nc3 Nf6 3. f4 d5 4. fxe5 Nxe4 5. Qf3 Nxc3 6. bxc3 Bc5 7. d4 Bb6 8.\n\nBd3 Ba5 9. Bd2 Nc6 10. Ne2 Be6 11. O-O Qd7 12. Nf4 Bg4 13. e6 Bxf3 14. exd7+\n\nKxd7 15. Rxf3 Nxd4 16. Rg3 g6 17. Nxd5 Rad8 18. Rg4 Ne6 19. Ra4 Bb6+ 20. Nxb6+\n\naxb6 21. Be3 Ke7 22. Ra7 Rb8 23. Be4 c6 24. Bxb6 Rhc8 25. a4 Kf8 26. a5 Nd8 27.\n\na6 bxa6 28. Bc5+ Kg8 29. R7xa6 Ne6 30. Be3 c5 31. Bd5 Nc7 32. Rd6 Nb5 33. Rc6\n\nNxc3 34. Rxc8+ Rxc8 35. Ra8 Rxa8 36. Bxa8 c4 37. Bd2 Nb1 38. Bc1 c3 39. Bd5 Kf8\n\n40. Ba2 Nd2 41. Kf2 Ke7 42. Bxd2 cxd2 43. Ke2 f5 44. Kxd2 g5 45. c4 f4 46. Bb3\n\nh5 47. Ba4 g4 48. Bb5 h4 49. c5 g3 50. hxg3 fxg3 51. c6 Kd6 52. Ke3 Kc7 53. Kf3\n\nKb6 54. Kg4 h3 55. Kxh3 Kxb5 56. c7 Kc4 57. c8=Q+ Kd3 58. Qe6 Kd4 59. Kxg3 Kc5\n\n60. Kf4 Kb5 61. g4 Kb4 62. g5 Kb5 63. g6 Kb4 64. g7 Kb5 65. g8=Q Kb4 66. Qc4+\n\nKa5 67. Qd8# 1-0\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'kingcheese00',
#    'black ': 'remyrouyer',
#    'result ': '0-1',
#    'whiteelo ': '1606',
#    'blackelo ': '1687',
#    'timecontrol ': '600',
#    'endtime ': '15:36:30 PDT',
#    'termination ': 'remyrouyer won by resignation',
#    'moves': '1. e4 e5 2. Nf3 Nf6 3. Nxe5 d6 4. Nxf7 Kxf7 5. Bc4+ Be6 6. Bxe6+ Kxe6 7. d3 Be7\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "kingcheese00"]\n\n[Black "remyrouyer"]\n\n[Result "0-1"]\n\n[WhiteElo "1606"]\n\n[BlackElo "1687"]\n\n[TimeControl "600"]\n\n[EndTime "15:36:30 PDT"]\n\n[Termination "remyrouyer won by resignation"]\n\n\n\n1. e4 e5 2. Nf3 Nf6 3. Nxe5 d6 4. Nxf7 Kxf7 5. Bc4+ Be6 6. Bxe6+ Kxe6 7. d3 Be7\n\n8. Nc3 Rf8 9. Bg5 Kf7 10. Bxf6 Bxf6 11. Qh5+ Kg8 12. Qd5+ Kh8 13. Qxb7 Nd7 14.\n\nQd5 Rb8 15. O-O-O Bxc3 16. bxc3 Rb6 17. f4 Qb8 18. Kd2 Rxf4 19. Rhf1 Rxf1 20.\n\nRxf1 Nf6 21. h3 Nxd5 0-1\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'remyrouyer',
#    'black ': 'sharanprabhu',
#    'result ': '0-1',
#    'whiteelo ': '1680',
#    'blackelo ': '1723',
#    'timecontrol ': '600',
#    'endtime ': '15:43:55 PDT',
#    'termination ': 'sharanprabhu won by resignation',
#    'moves': '1. e4 e5 2. Bc4 Nf6 3. d4 Nxe4 4. dxe5 Bc5 5. Qf3 d5 6. Be3 Bxe3 7. Bb5+ c6 8.\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "remyrouyer"]\n\n[Black "sharanprabhu"]\n\n[Result "0-1"]\n\n[WhiteElo "1680"]\n\n[BlackElo "1723"]\n\n[TimeControl "600"]\n\n[EndTime "15:43:55 PDT"]\n\n[Termination "sharanprabhu won by resignation"]\n\n\n\n1. e4 e5 2. Bc4 Nf6 3. d4 Nxe4 4. dxe5 Bc5 5. Qf3 d5 6. Be3 Bxe3 7. Bb5+ c6 8.\n\nBxc6+ bxc6 9. Qxe3 Qb6 10. Qxb6 axb6 11. Nf3 Bg4 12. Nbd2 Nd7 13. Nd4 c5 14. Nb5\n\nNxd2 15. Kxd2 Ra5 16. Nd6+ Ke7 17. f3 Bh5 18. g4 Bg6 19. f4 Rha8 20. f5 Nxe5 21.\n\nNb7 R5a7 22. fxg6 hxg6 23. Rhe1 f6 24. Nxc5 bxc5 25. h4 Kd6 26. h5 Nf3+ 27. Kd3\n\nNxe1+ 28. Rxe1 gxh5 29. gxh5 Rxa2 30. Rg1 R8a7 31. Ke3 Rxb2 32. Kf4 Rxc2 33. Kf5\n\nRf2+ 34. Kg4 d4 35. Kg3 Rf5 36. Kg4 Rg5+ 0-1\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'remyrouyer',
#    'black ': 'Scrollable',
#    'result ': '1-0',
#    'whiteelo ': '1687',
#    'blackelo ': '1637',
#    'timecontrol ': '600',
#    'endtime ': '15:53:30 PDT',
#    'termination ': 'remyrouyer won by resignation',
#    'moves': '1. e4 e5 2. Bc4 Nf6 3. d4 Nxe4 4. dxe5 Qh4 5. Qf3 f5 6. Qxf5 Be7 7. Qf7+ Kd8 8.\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "remyrouyer"]\n\n[Black "Scrollable"]\n\n[Result "1-0"]\n\n[WhiteElo "1687"]\n\n[BlackElo "1637"]\n\n[TimeControl "600"]\n\n[EndTime "15:53:30 PDT"]\n\n[Termination "remyrouyer won by resignation"]\n\n\n\n1. e4 e5 2. Bc4 Nf6 3. d4 Nxe4 4. dxe5 Qh4 5. Qf3 f5 6. Qxf5 Be7 7. Qf7+ Kd8 8.\n\ng3 Nxg3 9. fxg3 Qe4+ 10. Be2 Qxh1 11. Be3 Qxh2 12. Qxg7 Rf8 13. Nd2 Nc6 14.\n\nO-O-O d6 15. Bg5 dxe5 16. Qxf8+ 1-0\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'Ztla',
#    'black ': 'remyrouyer',
#    'result ': '1-0',
#    'whiteelo ': '1602',
#    'blackelo ': '1677',
#    'timecontrol ': '600',
#    'endtime ': '16:09:38 PDT',
#    'termination ': 'Ztla won by checkmate',
#    'moves': '1. d4 e5 2. dxe5 Bc5 3. Nf3 d5 4. Bf4 Ne7 5. e3 Bg4 6. Be2 Nbc6 7. Nbd2 h5 8.\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "Ztla"]\n\n[Black "remyrouyer"]\n\n[Result "1-0"]\n\n[WhiteElo "1602"]\n\n[BlackElo "1677"]\n\n[TimeControl "600"]\n\n[EndTime "16:09:38 PDT"]\n\n[Termination "Ztla won by checkmate"]\n\n\n\n1. d4 e5 2. dxe5 Bc5 3. Nf3 d5 4. Bf4 Ne7 5. e3 Bg4 6. Be2 Nbc6 7. Nbd2 h5 8.\n\nNd4 Bxe2 9. Qxe2 Nxd4 10. exd4 Bxd4 11. c3 Bb6 12. Nb3 Ng6 13. Be3 Bxe3 14. Qxe3\n\nQe7 15. f4 O-O-O 16. Nd4 Qd7 17. O-O h4 18. h3 Rde8 19. Rfe1 a6 20. Qd3 Nxf4 21.\n\nQf3 g5 22. Re3 Ng6 23. Rae1 Re7 24. Nf5 Re6 25. Nd4 Rb6 26. b4 Re8 27. a4 a5 28.\n\nb5 c5 29. bxc6 bxc6 30. Nf5 c5 31. Nd6+ Rxd6 32. exd6 Rxe3 33. Rxe3 Qxd6 34.\n\nQxf7 Ne5 35. Qe8+ Kc7 36. Rxe5 Qg6 37. Re7+ Kd6 38. Qd7# 1-0\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'Dimacs2',
#    'black ': 'remyrouyer',
#    'result ': '1-0',
#    'whiteelo ': '1728',
#    'blackelo ': '1670',
#    'timecontrol ': '600',
#    'endtime ': '16:24:06 PDT',
#    'termination ': 'Dimacs2 won by checkmate',
#    'moves': '1. e4 e5 2. Nf3 Nf6 3. Nc3 Nc6 4. Bb5 a6 5. Bxc6 dxc6 6. O-O Bd6 7. d4 Bg4 8. h3\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "Dimacs2"]\n\n[Black "remyrouyer"]\n\n[Result "1-0"]\n\n[WhiteElo "1728"]\n\n[BlackElo "1670"]\n\n[TimeControl "600"]\n\n[EndTime "16:24:06 PDT"]\n\n[Termination "Dimacs2 won by checkmate"]\n\n\n\n1. e4 e5 2. Nf3 Nf6 3. Nc3 Nc6 4. Bb5 a6 5. Bxc6 dxc6 6. O-O Bd6 7. d4 Bg4 8. h3\n\nBxf3 9. Qxf3 exd4 10. Ne2 O-O 11. Bg5 Be7 12. e5 Nd5 13. Bxe7 Nxe7 14. Rad1 c5\n\n15. c3 b6 16. cxd4 cxd4 17. Rxd4 Qe8 18. Rfd1 c5 19. Rh4 Ng6 20. Re4 Qb5 21. b4\n\nRae8 22. bxc5 Nxe5 23. Qg3 Qxc5 24. Re1 Ng6 25. Nc3 Rxe4 26. Nxe4 Qb4 27. Re3\n\nQb1+ 28. Kh2 Qxa2 29. Ng5 h6 30. Nf3 b5 31. Nh4 Nxh4 32. Qxh4 Qb2 33. Rg3 b4 34.\n\nQxh6 Qb3 35. Qxg7# 1-0\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'lpm1953',
#    'black ': 'remyrouyer',
#    'result ': '1-0',
#    'whiteelo ': '1677',
#    'blackelo ': '1662',
#    'timecontrol ': '600',
#    'endtime ': '17:00:36 PDT',
#    'termination ': 'lpm1953 won by resignation',
#    'moves': '1. e4 e5 2. Nf3 Nf6 3. Bc4 Nc6 4. Ng5 d5 5. exd5 Na5 6. Bb3 Nxb3 7. axb3 Nxd5 8.\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "lpm1953"]\n\n[Black "remyrouyer"]\n\n[Result "1-0"]\n\n[WhiteElo "1677"]\n\n[BlackElo "1662"]\n\n[TimeControl "600"]\n\n[EndTime "17:00:36 PDT"]\n\n[Termination "lpm1953 won by resignation"]\n\n\n\n1. e4 e5 2. Nf3 Nf6 3. Bc4 Nc6 4. Ng5 d5 5. exd5 Na5 6. Bb3 Nxb3 7. axb3 Nxd5 8.\n\nd3 Nf4 9. Bxf4 exf4 10. Qe2+ Be7 11. Nf3 O-O 12. Nbd2 Re8 13. Ne4 Bg4 14. O-O-O\n\nBb4 15. h3 Bxf3 16. Qxf3 a5 17. Qxf4 a4 18. c3 Be7 19. bxa4 Rxa4 20. Kc2 Bg5 21.\n\nNf6+ Qxf6 22. Qxa4 Qxf2+ 23. Kb1 h6 24. Qxe8+ Kh7 25. Qe4+ Kh8 26. Rhf1 Qb6 27.\n\nRxf7 Kg8 28. Qe8+ Kh7 29. Rf8 1-0\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'remyrouyer',
#    'black ': 'sreth',
#    'result ': '1/2-1/2',
#    'whiteelo ': '1661',
#    'blackelo ': '1598',
#    'timecontrol ': '600',
#    'endtime ': '17:20:26 PDT',
#    'termination ': 'Game drawn - insufficient material',
#    'moves': '1. e4 e5 2. Bc4 Nf6 3. d4 exd4 4. Nf3 h6 5. e5 Ne4 6. Qxd4 Nc5 7. b4 Nc6 8. Qd5\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "remyrouyer"]\n\n[Black "sreth"]\n\n[Result "1/2-1/2"]\n\n[WhiteElo "1661"]\n\n[BlackElo "1598"]\n\n[TimeControl "600"]\n\n[EndTime "17:20:26 PDT"]\n\n[Termination "Game drawn - insufficient material"]\n\n\n\n1. e4 e5 2. Bc4 Nf6 3. d4 exd4 4. Nf3 h6 5. e5 Ne4 6. Qxd4 Nc5 7. b4 Nc6 8. Qd5\n\nNe6 9. b5 Nb4 10. Qd2 d5 11. exd6 Qxd6 12. Bb3 Nc5 13. O-O Nxb3 14. axb3 Qxd2\n\n15. Bxd2 Nd5 16. c4 Nf6 17. Re1+ Be6 18. Nd4 Kd7 19. b4 Bxc4 20. Nc3 Re8 21.\n\nRxe8 Nxe8 22. Rxa7 Bxb4 23. Rxb7 Bxc3 24. Bxc3 Nd6 25. Ra7 Re8 26. b6 Bd5 27.\n\nbxc7 Rc8 28. Ba5 g5 29. g3 f5 30. Kf1 f4 31. g4 Bf7 32. Nf5 Nb5 33. Rb7 Nxc7 34.\n\nRxc7+ Rxc7 35. Bxc7 h5 36. Bb6 hxg4 37. Nh6 Be6 38. Ba5 g3 39. fxg3 fxg3 40.\n\nhxg3 Ke7 41. g4 Kf6 42. Kg2 Ke5 43. Kg3 Kf6 44. Bd8+ Kg6 45. Bxg5 Kxg5 46. Nf5\n\nBxf5 47. gxf5 Kxf5 1/2-1/2\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'remyrouyer',
#    'black ': 'phppp',
#    'result ': '0-1',
#    'whiteelo ': '1654',
#    'blackelo ': '1709',
#    'timecontrol ': '600',
#    'endtime ': '17:40:12 PDT',
#    'termination ': 'phppp won by checkmate',
#    'moves': '1. e4 d5 2. exd5 Qxd5 3. Nc3 Qd8 4. Nf3 Bf5 5. d4 e6 6. Bd3 Bg4 7. Be4 c6 8. Qd3\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "remyrouyer"]\n\n[Black "phppp"]\n\n[Result "0-1"]\n\n[WhiteElo "1654"]\n\n[BlackElo "1709"]\n\n[TimeControl "600"]\n\n[EndTime "17:40:12 PDT"]\n\n[Termination "phppp won by checkmate"]\n\n\n\n1. e4 d5 2. exd5 Qxd5 3. Nc3 Qd8 4. Nf3 Bf5 5. d4 e6 6. Bd3 Bg4 7. Be4 c6 8. Qd3\n\nNf6 9. Ne5 Bh5 10. Bf3 Bg6 11. Nxg6 hxg6 12. Bg5 Nbd7 13. Ne4 Qa5+ 14. Bd2 Qc7\n\n15. O-O-O a5 16. h4 a4 17. a3 Nxe4 18. Bxe4 Nf6 19. Bf3 Bd6 20. g4 Bf4 21. g5\n\nBxd2+ 22. Qxd2 Nh5 23. Rhe1 b5 24. d5 O-O 25. dxe6 fxe6 26. Rxe6 Rxf3 27. Rxg6\n\nQf4 28. Rxc6 Qxd2+ 29. Rxd2 Nf4 30. Rcd6 Rf8 31. g6 Rf6 32. Rd8+ Rf8 33. R8d6\n\nNg2 34. h5 Rxf2 35. Rxf2 Rxf2 36. Rd5 Ne3 37. Rxb5 Nc4 38. Rd5 Rf1+ 39. Rd1\n\nRxd1+ 40. Kxd1 Nxb2+ 41. Kd2 Nc4+ 42. Kc3 Nxa3 43. Kb4 Nxc2+ 44. Kxa4 Ne3 45.\n\nKb4 Nd5+ 46. Kc5 Nf4 47. Kd4 Nxh5 48. Ke5 Nf6 49. Kf5 Kf8 50. Kg5 Ke7 51. Kf5\n\nKd6 52. Kg5 Ke5 53. Kh4 Kf5 54. Kg3 Kxg6 55. Kg2 Kf5 56. Kg3 g5 57. Kg2 Ne4 58.\n\nKh3 g4+ 59. Kg2 Kf4 60. Kg1 g3 61. Kg2 Ke3 62. Kg1 Kf3 63. Kh1 g2+ 64. Kg1 Ng3\n\n65. Kh2 Kf2 66. Kh3 g1=Q 67. Kh4 Nf5+ 68. Kh5 Ne7 69. Kh6 Qg6# 0-1\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'remyrouyer',
#    'black ': 'CapivaraNeverEnds',
#    'result ': '1-0',
#    'whiteelo ': '1662',
#    'blackelo ': '1657',
#    'timecontrol ': '600',
#    'endtime ': '18:37:44 PDT',
#    'termination ': 'remyrouyer won by resignation',
#    'moves': '1. e4 Nf6 2. e5 Nd5 3. c4 Nb6 4. d4 d6 5. f4 dxe5 6. fxe5 Nc6 7. Nf3 Bg4 8. d5\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "remyrouyer"]\n\n[Black "CapivaraNeverEnds"]\n\n[Result "1-0"]\n\n[WhiteElo "1662"]\n\n[BlackElo "1657"]\n\n[TimeControl "600"]\n\n[EndTime "18:37:44 PDT"]\n\n[Termination "remyrouyer won by resignation"]\n\n\n\n1. e4 Nf6 2. e5 Nd5 3. c4 Nb6 4. d4 d6 5. f4 dxe5 6. fxe5 Nc6 7. Nf3 Bg4 8. d5\n\nNxe5 9. Be2 e6 10. Nc3 Nxf3+ 11. gxf3 Bf5 12. Be3 exd5 13. cxd5 Bb4 14. Qb3\n\nBxc3+ 15. Qxc3 Nxd5 16. Qe5+ Be6 17. O-O-O Qf6 18. Rxd5 Qxe5 19. Rxe5 O-O-O 20.\n\nBxa7 b6 21. Ba6+ Kd7 22. Rd1+ Kc6 23. f4 Ra8 24. Bb5+ Kb7 25. Bxb6 cxb6 26. a4\n\nRhd8 27. f5 Rxd1+ 28. Kxd1 Rd8+ 29. Kc1 Bb3 30. Re1 Kc7 31. h4 Kd6 32. Rd1+ Ke7\n\n33. Rxd8 Kxd8 34. Kd2 Ke7 35. Kc3 Bd1 36. Kd4 Kd6 37. b4 f6 38. a5 Kc7 39. a6\n\nBf3 40. Bd3 Kd6 41. a7 Bb7 42. Be4 Kc7 43. a8=Q Bxa8 44. Bxa8 Kd6 45. Bd5 Kd7\n\n46. Bg8 h6 47. h5 Kd6 48. Bf7 Kd7 49. Kd5 Kc7 50. Bg6 Kd7 51. b5 Kc7 52. Ke6 Kd8\n\n53. Kd6 Kc8 54. Kc6 1-0\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'remyrouyer',
#    'black ': 'Vara7',
#    'result ': '0-1',
#    'whiteelo ': '1654',
#    'blackelo ': '1685',
#    'timecontrol ': '600',
#    'endtime ': '18:51:06 PDT',
#    'termination ': 'Vara7 won by resignation',
#    'moves': '1. e4 e5 2. Bc4 f5 3. exf5 Nf6 4. Nf3 d5 5. Bb3 Bd6 6. d4 e4 7. Ne5 Bxf5 8. O-O\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "remyrouyer"]\n\n[Black "Vara7"]\n\n[Result "0-1"]\n\n[WhiteElo "1654"]\n\n[BlackElo "1685"]\n\n[TimeControl "600"]\n\n[EndTime "18:51:06 PDT"]\n\n[Termination "Vara7 won by resignation"]\n\n\n\n1. e4 e5 2. Bc4 f5 3. exf5 Nf6 4. Nf3 d5 5. Bb3 Bd6 6. d4 e4 7. Ne5 Bxf5 8. O-O\n\nNc6 9. Bxd5 Nxd5 10. Qh5+ g6 11. Qh6 Nxe5 12. Bg5 Qd7 13. Bf6 Nxf6 14. dxe5 Bxe5\n\n15. Nc3 Bxc3 16. Rad1 Ng4 17. Qg5 Bf6 0-1\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'maraccccc',
#    'black ': 'remyrouyer',
#    'result ': '0-1',
#    'whiteelo ': '1561',
#    'blackelo ': '1660',
#    'timecontrol ': '600',
#    'endtime ': '19:06:38 PDT',
#    'termination ': 'remyrouyer won by resignation',
#    'moves': '1. e4 e5 2. Nf3 Nf6 3. Bc4 Nc6 4. d3 Bc5 5. c3 O-O 6. O-O a6 7. a4 Ba7 8. h3 b5\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "maraccccc"]\n\n[Black "remyrouyer"]\n\n[Result "0-1"]\n\n[WhiteElo "1561"]\n\n[BlackElo "1660"]\n\n[TimeControl "600"]\n\n[EndTime "19:06:38 PDT"]\n\n[Termination "remyrouyer won by resignation"]\n\n\n\n1. e4 e5 2. Nf3 Nf6 3. Bc4 Nc6 4. d3 Bc5 5. c3 O-O 6. O-O a6 7. a4 Ba7 8. h3 b5\n\n9. Bb3 d6 10. Bg5 Na5 11. Nbd2 Nxb3 12. Nxb3 Bd7 13. axb5 axb5 14. Re1 c5 15.\n\nNbd2 h6 16. Bh4 Re8 17. Nf1 Re6 18. N1h2 Qb6 19. Qd2 g5 20. Bxg5 hxg5 21. Qxg5+\n\nKf8 22. Nh4 c4 23. d4 exd4 24. Ng4 dxc3 25. Re2 Nxg4 26. Qxg4 Re7 27. Qg5 Rxe4\n\n28. Qh6+ Kg8 29. Qg5+ Kf8 30. Qh6+ Kg8 31. Qg5+ Kh7 32. Qh5+ Kg7 33. Rxe4 Qxf2+\n\n34. Kh2 cxb2 35. Qg5+ Kf8 36. Qe7+ Kg8 37. Qg5+ Kf8 38. Rf4 Qxf4+ 39. Qxf4\n\nbxa1=Q 40. Ng6+ Kg7 0-1\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'tusharnargunde',
#    'black ': 'remyrouyer',
#    'result ': '1-0',
#    'whiteelo ': '1641',
#    'blackelo ': '1651',
#    'timecontrol ': '600',
#    'endtime ': '19:22:42 PDT',
#    'termination ': 'tusharnargunde won by resignation',
#    'moves': '1. d4 e5 2. dxe5 Bc5 3. e4 d6 4. exd6 Ne7 5. dxe7 Bxf2+ 6. Ke2 Bg4+ 7. Nf3 Qxd1+\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "tusharnargunde"]\n\n[Black "remyrouyer"]\n\n[Result "1-0"]\n\n[WhiteElo "1641"]\n\n[BlackElo "1651"]\n\n[TimeControl "600"]\n\n[EndTime "19:22:42 PDT"]\n\n[Termination "tusharnargunde won by resignation"]\n\n\n\n1. d4 e5 2. dxe5 Bc5 3. e4 d6 4. exd6 Ne7 5. dxe7 Bxf2+ 6. Ke2 Bg4+ 7. Nf3 Qxd1+\n\n8. Kxd1 Kxe7 9. Ke2 Bd4 10. c3 Bb6 11. Be3 Rd8 12. Nd2 Nc6 13. h3 Bxf3+ 14. Nxf3\n\nBxe3 15. Kxe3 h6 16. Bb5 Rd6 17. Rad1 Re6 18. Bxc6 Rxc6 19. Rd4 g5 20. Rhd1 Ke6\n\n21. Rd5 f6 22. Nd4+ 1-0\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'kwokc',
#    'black ': 'remyrouyer',
#    'result ': '0-1',
#    'whiteelo ': '1689',
#    'blackelo ': '1660',
#    'timecontrol ': '600',
#    'endtime ': '19:29:02 PDT',
#    'termination ': 'remyrouyer won by resignation',
#    'moves': '1. d4 e5 2. dxe5 Bc5 3. Nf3 d5 4. exd6 Ne7 5. dxe7 Bxf2+ 6. Kxf2 Qxd1 7. Nc3\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "kwokc"]\n\n[Black "remyrouyer"]\n\n[Result "0-1"]\n\n[WhiteElo "1689"]\n\n[BlackElo "1660"]\n\n[TimeControl "600"]\n\n[EndTime "19:29:02 PDT"]\n\n[Termination "remyrouyer won by resignation"]\n\n\n\n1. d4 e5 2. dxe5 Bc5 3. Nf3 d5 4. exd6 Ne7 5. dxe7 Bxf2+ 6. Kxf2 Qxd1 7. Nc3\n\nQxc2 8. Bf4 Qxb2 9. Rc1 Qb6+ 10. Be3 Qe6 11. Nb5 Na6 12. Nfd4 Qf6+ 13. Kg1 c6\n\n14. Nc3 Qxe7 15. Bf2 O-O 16. Nf5 Bxf5 0-1\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'remyrouyer',
#    'black ': 'herpos',
#    'result ': '0-1',
#    'whiteelo ': '1651',
#    'blackelo ': '1611',
#    'timecontrol ': '600',
#    'endtime ': '19:31:49 PDT',
#    'termination ': 'herpos won by resignation',
#    'moves': '1. e4 c5 2. c3 e5 3. d4 cxd4 4. cxd4 exd4 5. Qxd4 Nc6 6. Qa4 d6 7. Bb5 Bd7 8.\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "remyrouyer"]\n\n[Black "herpos"]\n\n[Result "0-1"]\n\n[WhiteElo "1651"]\n\n[BlackElo "1611"]\n\n[TimeControl "600"]\n\n[EndTime "19:31:49 PDT"]\n\n[Termination "herpos won by resignation"]\n\n\n\n1. e4 c5 2. c3 e5 3. d4 cxd4 4. cxd4 exd4 5. Qxd4 Nc6 6. Qa4 d6 7. Bb5 Bd7 8.\n\nNc3 Nf6 9. Qb3 Be7 10. Bc4 O-O 11. Bg5 Na5 12. Qb4 d5 13. Nxd5 Bxb4+ 14. Nxb4\n\nNxc4 0-1\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'remyrouyer',
#    'black ': 'mikay020319',
#    'result ': '1-0',
#    'whiteelo ': '1659',
#    'blackelo ': '1633',
#    'timecontrol ': '600',
#    'endtime ': '19:39:48 PDT',
#    'termination ': 'remyrouyer won by checkmate',
#    'moves': '1. e4 c5 2. c3 Qa5 3. Bc4 e6 4. Nf3 g6 5. O-O Bg7 6. e5 Qc7 7. Na3 a6 8. Re1 b5\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "remyrouyer"]\n\n[Black "mikay020319"]\n\n[Result "1-0"]\n\n[WhiteElo "1659"]\n\n[BlackElo "1633"]\n\n[TimeControl "600"]\n\n[EndTime "19:39:48 PDT"]\n\n[Termination "remyrouyer won by checkmate"]\n\n\n\n1. e4 c5 2. c3 Qa5 3. Bc4 e6 4. Nf3 g6 5. O-O Bg7 6. e5 Qc7 7. Na3 a6 8. Re1 b5\n\n9. Bb3 Bb7 10. d4 c4 11. Bc2 d6 12. Bf4 d5 13. Nb1 Nd7 14. Nbd2 Nh6 15. b3 f5\n\n16. exf6 Qxf4 17. fxg7 Rg8 18. Rxe6+ Kf7 19. Qe1 Nf5 20. Bxf5 Qxf5 21. Re7+ Kf6\n\n22. Qe5+ Qxe5 23. dxe5+ Kxe7 24. Re1 Rxg7 25. e6 Nf6 26. Ng5 h6 27. Nf7 Ne4 28.\n\nNxe4 dxe4 29. Nxh6 Kxe6 30. f3 Ke5 31. Ng4+ Kf4 32. g3+ Kxf3 33. Ne5# 1-0\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'remyrouyer',
#    'black ': 'RjD2017',
#    'result ': '1-0',
#    'whiteelo ': '1667',
#    'blackelo ': '1645',
#    'timecontrol ': '600',
#    'endtime ': '19:53:41 PDT',
#    'termination ': 'remyrouyer won by resignation',
#    'moves': '1. e4 c5 2. c3 e6 3. d4 b6 4. d5 g6 5. Nf3 Bg7 6. Bb5 a6 7. Ba4 b5 8. Bc2 Bb7 9.\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "remyrouyer"]\n\n[Black "RjD2017"]\n\n[Result "1-0"]\n\n[WhiteElo "1667"]\n\n[BlackElo "1645"]\n\n[TimeControl "600"]\n\n[EndTime "19:53:41 PDT"]\n\n[Termination "remyrouyer won by resignation"]\n\n\n\n1. e4 c5 2. c3 e6 3. d4 b6 4. d5 g6 5. Nf3 Bg7 6. Bb5 a6 7. Ba4 b5 8. Bc2 Bb7 9.\n\nd6 Nf6 10. e5 Nd5 11. O-O O-O 12. Be4 Bc6 13. b3 f6 14. Qc2 fxe5 15. Bg5 Qb6 16.\n\nBxd5 Bxd5 17. Be7 Rxf3 18. gxf3 Bxf3 19. Nd2 Bg4 20. Qe4 Bh3 21. Qxa8 Bxf1 22.\n\nRxf1 Bh6 23. Ne4 Kf7 24. Ng3 Nc6 25. Qh8 Nxe7 26. Qxh7+ Bg7 27. dxe7 Qb8 28. Ne4\n\nQe8 1-0\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'paras1965',
#    'black ': 'remyrouyer',
#    'result ': '0-1',
#    'whiteelo ': '1666',
#    'blackelo ': '1675',
#    'timecontrol ': '600',
#    'endtime ': '19:58:43 PDT',
#    'termination ': 'remyrouyer won by resignation',
#    'moves': '1. e4 e5 2. Nf3 Nf6 3. Nxe5 d6 4. Nc4 Nxe4 5. d3 Nf6 6. Bg5 Be7 7. Nc3 d5 8. Ne3\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "paras1965"]\n\n[Black "remyrouyer"]\n\n[Result "0-1"]\n\n[WhiteElo "1666"]\n\n[BlackElo "1675"]\n\n[TimeControl "600"]\n\n[EndTime "19:58:43 PDT"]\n\n[Termination "remyrouyer won by resignation"]\n\n\n\n1. e4 e5 2. Nf3 Nf6 3. Nxe5 d6 4. Nc4 Nxe4 5. d3 Nf6 6. Bg5 Be7 7. Nc3 d5 8. Ne3\n\nd4 9. Nc4 dxc3 10. bxc3 Be6 11. Ne3 O-O 12. c4 Bb4+ 13. Ke2 Bc3 14. Rb1 b6 15.\n\nRb3 Bd4 16. c3 Bxe3 17. fxe3 Bg4+ 0-1\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'damianalbrecht',
#    'black ': 'remyrouyer',
#    'result ': '0-1',
#    'whiteelo ': '1586',
#    'blackelo ': '1681',
#    'timecontrol ': '600',
#    'endtime ': '20:01:40 PDT',
#    'termination ': 'remyrouyer won by resignation',
#    'moves': '1. e4 e5 2. Nf3 Nf6 3. Nxe5 d6 4. Nf3 Nxe4 5. Qe2 Qe7 6. Nc3 Nxc3 7. dxc3 Bg4 8.\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "damianalbrecht"]\n\n[Black "remyrouyer"]\n\n[Result "0-1"]\n\n[WhiteElo "1586"]\n\n[BlackElo "1681"]\n\n[TimeControl "600"]\n\n[EndTime "20:01:40 PDT"]\n\n[Termination "remyrouyer won by resignation"]\n\n\n\n1. e4 e5 2. Nf3 Nf6 3. Nxe5 d6 4. Nf3 Nxe4 5. Qe2 Qe7 6. Nc3 Nxc3 7. dxc3 Bg4 8.\n\nQxe7+ Bxe7 9. Be2 O-O 10. Bg5 Bxg5 11. Nxg5 Bxe2 12. Kxe2 Re8+ 13. Kd2 Nc6 14.\n\nRae1 h6 15. Nf3 Ne5 16. Nxe5 dxe5 17. Re4 Rad8+ 18. Kc1 f5 19. Re2 e4 20. Rhe1\n\nKf7 21. f3 exf3 22. Rxe8 Rxe8 23. Rxe8 f2 0-1\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'ningombamsingh',
#    'black ': 'remyrouyer',
#    'result ': '0-1',
#    'whiteelo ': '1708',
#    'blackelo ': '1690',
#    'timecontrol ': '600',
#    'endtime ': '20:22:38 PDT',
#    'termination ': 'remyrouyer won on time',
#    'moves': '1. e4 e5 2. Nf3 Nf6 3. Bc4 Nc6 4. d3 Bc5 5. c3 d5 6. exd5 Nxd5 7. O-O O-O 8. a4\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "ningombamsingh"]\n\n[Black "remyrouyer"]\n\n[Result "0-1"]\n\n[WhiteElo "1708"]\n\n[BlackElo "1690"]\n\n[TimeControl "600"]\n\n[EndTime "20:22:38 PDT"]\n\n[Termination "remyrouyer won on time"]\n\n\n\n1. e4 e5 2. Nf3 Nf6 3. Bc4 Nc6 4. d3 Bc5 5. c3 d5 6. exd5 Nxd5 7. O-O O-O 8. a4\n\nBg4 9. Nbd2 Nf4 10. Qc2 Ne2+ 11. Kh1 Qf6 12. Ne4 Qf5 13. Qxe2 Qh5 14. Nxc5 e4\n\n15. Nxe4 Rfe8 16. Be3 Ne5 17. Ng3 Qg6 18. Qd2 Bxf3 19. gxf3 Rad8 20. Qe2 Qf6 21.\n\nNe4 Qh4 22. Rg1 Qh5 23. Rg3 Nxc4 24. dxc4 Rxe4 25. Rag1 g6 26. Qc2 f5 27. fxe4\n\nQf3+ 28. R3g2 fxe4 29. b4 Rd3 30. Bd4 b6 31. c5 bxc5 32. bxc5 c6 33. Qb3+ Kf8\n\n34. Qb8+ Ke7 35. Qc7+ Ke6 36. Qxc6+ Ke7 37. Qd6+ Kf7 38. c6 g5 39. Qd7+ Kg6 40.\n\nc7 e3 41. Qe8+ Kh6 42. c8=Q exf2 43. Bxf2 g4 44. Qf8+ Qxf8 45. Qxf8+ Kg5 46.\n\nQg7+ Kf5 47. Rxg4 Ke6 48. Re1+ Kd6 49. Qe5+ Kc6 50. Qc5+ Kd7 51. Rg7+ Kd8 0-1\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'remyrouyer',
#    'black ': 'juankillerchess',
#    'result ': '1/2-1/2',
#    'whiteelo ': '1691',
#    'blackelo ': '1738',
#    'timecontrol ': '600',
#    'endtime ': '20:33:54 PDT',
#    'termination ': 'Game drawn by repetition',
#    'moves': '1. e4 e5 2. Bc4 d6 3. Nf3 Be7 4. d4 exd4 5. Nxd4 c5 6. Nf3 Nc6 7. O-O Nf6 8. e5\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "remyrouyer"]\n\n[Black "juankillerchess"]\n\n[Result "1/2-1/2"]\n\n[WhiteElo "1691"]\n\n[BlackElo "1738"]\n\n[TimeControl "600"]\n\n[EndTime "20:33:54 PDT"]\n\n[Termination "Game drawn by repetition"]\n\n\n\n1. e4 e5 2. Bc4 d6 3. Nf3 Be7 4. d4 exd4 5. Nxd4 c5 6. Nf3 Nc6 7. O-O Nf6 8. e5\n\ndxe5 9. Qxd8+ Bxd8 10. Re1 e4 11. Bg5 O-O 12. Bxf6 Bxf6 13. Nc3 exf3 14. Ne4\n\nBxb2 15. Ng5 Bxa1 16. Bxf7+ Kh8 17. Bd5 Nd4 18. Nf7+ Kg8 19. Nh6+ Kh8 20. Nf7+\n\nKg8 21. Nh6+ Kh8 22. Nf7+ 1/2-1/2\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'remyrouyer',
#    'black ': 'ImamHambali12',
#    'result ': '1-0',
#    'whiteelo ': '1696',
#    'blackelo ': '1538',
#    'timecontrol ': '600',
#    'endtime ': '20:54:46 PDT',
#    'termination ': 'remyrouyer won on time',
#    'moves': '1. e4 e5 2. Bc4 c6 3. Nf3 d5 4. exd5 cxd5 5. Bb5+ Bd7 6. Bxd7+ Nxd7 7. Qe2 Bd6\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "remyrouyer"]\n\n[Black "ImamHambali12"]\n\n[Result "1-0"]\n\n[WhiteElo "1696"]\n\n[BlackElo "1538"]\n\n[TimeControl "600"]\n\n[EndTime "20:54:46 PDT"]\n\n[Termination "remyrouyer won on time"]\n\n\n\n1. e4 e5 2. Bc4 c6 3. Nf3 d5 4. exd5 cxd5 5. Bb5+ Bd7 6. Bxd7+ Nxd7 7. Qe2 Bd6\n\n8. d4 e4 9. Nfd2 h6 10. Qb5 Ne7 11. Nc3 b6 12. Nxd5 a6 13. Qb3 f5 14. O-O Nxd5\n\n15. Qxd5 Be7 16. Qxf5 Rc8 17. Qg6+ Kf8 18. Qxe4 Kf7 19. Nb3 Nf6 20. Qf3 Rf8 21.\n\nc3 Kg8 22. Qg3 Kh7 23. Qd3+ Kh8 24. Be3 a5 25. h3 Nd5 26. c4 Nb4 27. Qe2 a4 28.\n\na3 Nc6 29. d5 Ne5 30. Nd2 Bf6 31. Rac1 Re8 32. Nf3 Nxf3+ 33. Qxf3 Bg5 34. Bxg5\n\nQxg5 35. Rfd1 Rf8 36. Qe3 Qf6 37. d6 Rcd8 38. Qd2 Rd7 39. f3 Rfd8 40. Qc3 Qf4\n\n41. Rd4 Qg5 42. Rcd1 Qe5 43. Qd3 Qc5 44. Kh1 Kg8 45. Rd5 Qc6 46. Qg6 Qxc4 47.\n\nQe6+ Kh8 48. Qe4 Qb3 49. Qe2 Kg8 50. Qe6+ Kh8 51. Qxh6+ 1-0\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'remyrouyer',
#    'black ': 'SandeepPanda',
#    'result ': '0-1',
#    'whiteelo ': '1687',
#    'blackelo ': '1655',
#    'timecontrol ': '600',
#    'endtime ': '21:55:27 PDT',
#    'termination ': 'SandeepPanda won by resignation',
#    'moves': '1. e4 c5 2. c3 d6 3. d4 cxd4 4. cxd4 Nf6 5. e5 dxe5 6. Qa4+ Nc6 7. dxe5 Nd5 8.\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "remyrouyer"]\n\n[Black "SandeepPanda"]\n\n[Result "0-1"]\n\n[WhiteElo "1687"]\n\n[BlackElo "1655"]\n\n[TimeControl "600"]\n\n[EndTime "21:55:27 PDT"]\n\n[Termination "SandeepPanda won by resignation"]\n\n\n\n1. e4 c5 2. c3 d6 3. d4 cxd4 4. cxd4 Nf6 5. e5 dxe5 6. Qa4+ Nc6 7. dxe5 Nd5 8.\n\nNf3 Bd7 9. Bb5 e6 10. O-O Be7 11. Rd1 O-O 12. Nc3 Nxc3 13. bxc3 Qc7 14. Be3 a6\n\n15. Bxc6 Bxc6 16. Qg4 Bxf3 17. Qxf3 Qxc3 18. Rdc1 Qxe5 19. Rab1 b5 20. Bf4 Qf5\n\n21. Rc7 Qxb1+ 22. Bc1 Rac8 23. Rxc8 Rxc8 24. h3 Qxc1+ 25. Kh2 Bd6+ 26. g3 Qd2\n\n27. Kg2 g6 28. Qb7 Rd8 29. Qb6 Qd5+ 30. Kg1 Bc5 31. Qxa6 Qd1+ 32. Kg2 Qe2 0-1\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'PrawiraNingrat82',
#    'black ': 'remyrouyer',
#    'result ': '1-0',
#    'whiteelo ': '1675',
#    'blackelo ': '1679',
#    'timecontrol ': '600',
#    'endtime ': '22:10:10 PDT',
#    'termination ': 'PrawiraNingrat82 won by checkmate',
#    'moves': '1. e3 e5 2. b3 d5 3. Bb2 Nc6 4. Bb5 e4 5. Bxc6+ bxc6 6. d3 f5 7. Qh5+ g6 8. Qe2\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "PrawiraNingrat82"]\n\n[Black "remyrouyer"]\n\n[Result "1-0"]\n\n[WhiteElo "1675"]\n\n[BlackElo "1679"]\n\n[TimeControl "600"]\n\n[EndTime "22:10:10 PDT"]\n\n[Termination "PrawiraNingrat82 won by checkmate"]\n\n\n\n1. e3 e5 2. b3 d5 3. Bb2 Nc6 4. Bb5 e4 5. Bxc6+ bxc6 6. d3 f5 7. Qh5+ g6 8. Qe2\n\nNf6 9. Nd2 Ba6 10. f3 Bg7 11. fxe4 f4 12. exf4 O-O 13. e5 Nh5 14. g3 c5 15.\n\nO-O-O Qc8 16. Ngf3 Rb8 17. Qe3 d4 18. Qf2 Bb7 19. Nc4 Qg4 20. Rdf1 a5 21. Nxa5\n\nBd5 22. Nc4 Ra8 23. a4 Rfb8 24. Ba3 Bf8 25. Rhg1 Kf7 26. Ng5+ Kg7 27. h3 Qd7 28.\n\ng4 h6 29. Ne4 Bxe4 30. dxe4 Nxf4 31. Qxf4 Be7 32. Qf7+ Kh8 33. Bxc5 Bg5+ 34. Kd1\n\nQxf7 35. Rxf7 Rd8 36. Rgf1 Ra6 37. Rf8+ Rxf8 38. Rxf8+ Kg7 39. Rc8 Rc6 40. b4\n\nBe3 41. Nxe3 dxe3 42. Ke2 h5 43. Kxe3 hxg4 44. hxg4 Kh6 45. a5 Kg5 46. Kf3 Kh4\n\n47. Rh8+ Kg5 48. c3 Re6 49. Bd4 c6 50. a6 Re7 51. a7 c5 52. Bxc5 Rc7 53. a8=Q\n\nRh7 54. Qd8+ Kh6 55. g5+ Kg7 56. Qf8# 1-0\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'Saragih2021',
#    'black ': 'remyrouyer',
#    'result ': '1-0',
#    'whiteelo ': '1664',
#    'blackelo ': '1670',
#    'timecontrol ': '600',
#    'endtime ': '22:23:59 PDT',
#    'termination ': 'Saragih2021 won by checkmate',
#    'moves': '1. e4 e5 2. f4 exf4 3. Nf3 Nc6 4. d4 Nf6 5. Nc3 Bb4 6. Bd3 O-O 7. Kf1 Re8 8.\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "Saragih2021"]\n\n[Black "remyrouyer"]\n\n[Result "1-0"]\n\n[WhiteElo "1664"]\n\n[BlackElo "1670"]\n\n[TimeControl "600"]\n\n[EndTime "22:23:59 PDT"]\n\n[Termination "Saragih2021 won by checkmate"]\n\n\n\n1. e4 e5 2. f4 exf4 3. Nf3 Nc6 4. d4 Nf6 5. Nc3 Bb4 6. Bd3 O-O 7. Kf1 Re8 8.\n\nBxf4 Bxc3 9. bxc3 Nxe4 10. Bxe4 Rxe4 11. Qd3 Rxf4 12. g3 Rf6 13. Kg2 d5 14. Rhf1\n\nBf5 15. Qb5 Be4 16. Rae1 a6 17. Qxb7 Na5 18. Qb4 Nc6 19. Qc5 Bxf3+ 20. Rxf3 Rxf3\n\n21. Kxf3 Na7 22. Re7 Rc8 23. Re5 Qf6+ 24. Kg2 Nb5 25. a4 Nd6 26. Rxd5 Ne4 27.\n\nQa7 Nxc3 28. Re5 Qc6+ 29. Kh3 Qd7+ 30. Kg2 Qxa4 31. Rc5 Qxc2+ 32. Kh3 Rf8 33.\n\nQxc7 Nb5 34. Rxc2 Nxc7 35. Rxc7 Ra8 36. d5 Kf8 37. d6 Ke8 38. Re7+ Kf8 39. Rc7\n\na5 40. d7 Ke7 41. Rc8 Rxc8 42. dxc8=Q a4 43. Qc5+ Kd7 44. Qb5+ Ke6 45. Qxa4 g5\n\n46. Qb5 Kf6 47. g4 Kg6 48. Qc6+ f6 49. Kg3 h6 50. h4 h5 51. gxh5+ Kxh5 52. Qf3+\n\nKg6 53. h5+ Kh6 54. Kg4 f5+ 55. Qxf5 Kg7 56. Qxg5+ Kh8 57. h6 Kh7 58. Qg7# 1-0\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'gulali77',
#    'black ': 'remyrouyer',
#    'result ': '1-0',
#    'whiteelo ': '1717',
#    'blackelo ': '1663',
#    'timecontrol ': '600',
#    'endtime ': '22:33:07 PDT',
#    'termination ': 'gulali77 won by resignation',
#    'moves': '1. d4 e5 2. dxe5 Bc5 3. e6 fxe6 4. e3 Nf6 5. Be2 Nc6 6. Bh5+ g6 7. Bf3 d5 8. b3\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "gulali77"]\n\n[Black "remyrouyer"]\n\n[Result "1-0"]\n\n[WhiteElo "1717"]\n\n[BlackElo "1663"]\n\n[TimeControl "600"]\n\n[EndTime "22:33:07 PDT"]\n\n[Termination "gulali77 won by resignation"]\n\n\n\n1. d4 e5 2. dxe5 Bc5 3. e6 fxe6 4. e3 Nf6 5. Be2 Nc6 6. Bh5+ g6 7. Bf3 d5 8. b3\n\nBd7 9. Bb2 Be7 10. Na3 a6 11. c4 Rf8 12. cxd5 exd5 13. Bxd5 Nxd5 14. Qxd5 Bb4+\n\n15. Kf1 Ne7 16. Qxb7 Bxa3 17. Bxa3 Bb5+ 18. Ne2 Qd2 19. Qxa8+ Kf7 20. Qf3+ Kg7\n\n21. Qg4 Rf7 22. Qd4+ Qxd4 23. exd4 Nf5 24. g3 Ne3+ 25. Ke1 Nc2+ 26. Kd2 Nxa3 27.\n\nf4 Re7 28. Rhe1 a5 29. Nc3 Rxe1 30. Rxe1 Bd7 31. Re7+ 1-0\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'remyrouyer',
#    'black ': 'Pepekvak',
#    'result ': '0-1',
#    'whiteelo ': '1656',
#    'blackelo ': '1708',
#    'timecontrol ': '600',
#    'endtime ': '22:47:24 PDT',
#    'termination ': 'Pepekvak won by checkmate',
#    'moves': '1. e4 c5 2. c3 Nc6 3. d3 e6 4. d4 cxd4 5. cxd4 d5 6. exd5 Qxd5 7. Nf3 Bb4+ 8.\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "remyrouyer"]\n\n[Black "Pepekvak"]\n\n[Result "0-1"]\n\n[WhiteElo "1656"]\n\n[BlackElo "1708"]\n\n[TimeControl "600"]\n\n[EndTime "22:47:24 PDT"]\n\n[Termination "Pepekvak won by checkmate"]\n\n\n\n1. e4 c5 2. c3 Nc6 3. d3 e6 4. d4 cxd4 5. cxd4 d5 6. exd5 Qxd5 7. Nf3 Bb4+ 8.\n\nNc3 Nf6 9. a3 Qa5 10. Bd2 Be7 11. b4 Qc7 12. Nb5 Qd7 13. Bf4 Nd5 14. Bg3 a6 15.\n\nQa4 Bd8 16. Nd6+ Ke7 17. Nxc8+ Rxc8 18. Bc4 Nb6 19. Qb3 Nxd4 20. Nxd4 Nxc4 21.\n\nQd3 Bb6 22. O-O Qxd4 23. Qxd4 Bxd4 24. Rac1 Nxa3 25. Rxc8 Rxc8 26. Rd1 e5 27. h3\n\nRc4 28. Kh1 Rxb4 29. f4 f6 30. fxe5 fxe5 31. Rd3 Nc4 32. h4 a5 33. h5 a4 34. h6\n\ngxh6 35. Bh4+ Kf7 36. Rf3+ Ke6 37. Rf6+ Kd5 38. Rxh6 a3 39. Be7 Ra4 40. Rxh7 a2\n\n41. Rh8 a1=Q+ 42. Kh2 Qg1+ 43. Kg3 Qf2+ 44. Kh2 Bc5 45. Rd8+ Nd6 46. Rf8 Rh4+\n\n47. Bxh4 Qxh4# 0-1\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'remyrouyer',
#    'black ': 'nileesh',
#    'result ': '1-0',
#    'whiteelo ': '1664',
#    'blackelo ': '1666',
#    'timecontrol ': '600',
#    'endtime ': '22:51:48 PDT',
#    'termination ': 'remyrouyer won by resignation',
#    'moves': '1. e4 c5 2. c3 d6 3. d4 cxd4 4. cxd4 Nf6 5. Nc3 Bg4 6. Nf3 Nc6 7. h3 Bh5 8. Be2\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "remyrouyer"]\n\n[Black "nileesh"]\n\n[Result "1-0"]\n\n[WhiteElo "1664"]\n\n[BlackElo "1666"]\n\n[TimeControl "600"]\n\n[EndTime "22:51:48 PDT"]\n\n[Termination "remyrouyer won by resignation"]\n\n\n\n1. e4 c5 2. c3 d6 3. d4 cxd4 4. cxd4 Nf6 5. Nc3 Bg4 6. Nf3 Nc6 7. h3 Bh5 8. Be2\n\nQa5 9. O-O Rd8 10. d5 Ne5 11. Nxe5 Bxe2 12. Qxe2 dxe5 13. Bd2 g6 14. Nb5 Qb6 15.\n\nBe3 Qa5 16. Bxa7 Bg7 17. a4 O-O 18. Bc5 Rfe8 19. b4 Qa8 20. Nc7 Qc8 21. Nxe8\n\nNxe8 22. Bxe7 1-0\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'remyrouyer',
#    'black ': 'ningombamsingh',
#    'result ': '0-1',
#    'whiteelo ': '1657',
#    'blackelo ': '1725',
#    'timecontrol ': '600',
#    'endtime ': '22:58:33 PDT',
#    'termination ': 'ningombamsingh won by resignation',
#    'moves': '1. e4 c5 2. c3 Nc6 3. d4 cxd4 4. cxd4 e6 5. d5 exd5 6. exd5 Nb4 7. d6 Qa5 8.\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "remyrouyer"]\n\n[Black "ningombamsingh"]\n\n[Result "0-1"]\n\n[WhiteElo "1657"]\n\n[BlackElo "1725"]\n\n[TimeControl "600"]\n\n[EndTime "22:58:33 PDT"]\n\n[Termination "ningombamsingh won by resignation"]\n\n\n\n1. e4 c5 2. c3 Nc6 3. d4 cxd4 4. cxd4 e6 5. d5 exd5 6. exd5 Nb4 7. d6 Qa5 8.\n\nQe2+ Kd8 9. Bd2 Nc2+ 10. Kd1 Qc5 11. Nf3 Nxa1 12. Nc3 Bxd6 13. Ne5 Bxe5 0-1\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'UmAsKhaM',
#    'black ': 'remyrouyer',
#    'result ': '1-0',
#    'whiteelo ': '1669',
#    'blackelo ': '1649',
#    'timecontrol ': '600',
#    'endtime ': '23:14:13 PDT',
#    'termination ': 'UmAsKhaM won by checkmate',
#    'moves': '1. e4 e5 2. Nf3 Nf6 3. Bc4 Nc6 4. Ng5 d5 5. exd5 Na5 6. Bb5+ c6 7. dxc6 bxc6 8.\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "UmAsKhaM"]\n\n[Black "remyrouyer"]\n\n[Result "1-0"]\n\n[WhiteElo "1669"]\n\n[BlackElo "1649"]\n\n[TimeControl "600"]\n\n[EndTime "23:14:13 PDT"]\n\n[Termination "UmAsKhaM won by checkmate"]\n\n\n\n1. e4 e5 2. Nf3 Nf6 3. Bc4 Nc6 4. Ng5 d5 5. exd5 Na5 6. Bb5+ c6 7. dxc6 bxc6 8.\n\nBa4 h6 9. Nf3 e4 10. Ne5 Bd7 11. Nxd7 Qxd7 12. O-O Bc5 13. d3 O-O 14. c3 exd3\n\n15. b4 Bxf2+ 16. Rxf2 Nc4 17. Bxh6 Ng4 18. Rf4 Nge3 19. Qf3 gxh6 20. Bxc6 Qd6\n\n21. Bxa8 d2 22. Rd4 Qxd4 23. cxd4 d1=Q+ 24. Qxd1 Nxd1 25. Bc6 Rb8 26. b5 Rc8 27.\n\na4 Rc7 28. Na3 Nxa3 29. Rxa3 Re7 30. h3 Re1+ 31. Kh2 Nf2 32. d5 h5 33. Kg3 Ne4+\n\n34. Kh4 Rg1 35. Kxh5 Nf6+ 36. Kh4 Rxg2 37. Rg3+ Rxg3 38. Kxg3 Kf8 39. Kf4 Ke7\n\n40. Kf5 Ng8 41. h4 Kd6 42. h5 Ke7 43. Kg5 f6+ 44. Kf5 Kf7 45. d6 Nh6+ 46. Kf4\n\nNg8 47. d7 Ke7 48. Kf5 Nh6+ 49. Kg6 Ng8 50. h6 Nxh6 51. Kxh6 f5 52. Kg5 f4 53.\n\nKxf4 Kd8 54. Ke5 Kc7 55. Ke6 a6 56. Ke7 axb5 57. axb5 Kb6 58. Bb7 Kc5 59. d8=R\n\nKxb5 60. Ba6+ Kxa6 61. Kd6 Kb5 62. Rc8 Kb6 63. Rb8+ Ka5 64. Kc5 Ka4 65. Kc4 Ka3\n\n66. Kc3 Ka2 67. Kc2 Ka1 68. Rb7 Ka2 69. Ra7# 1-0\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'piyushdhb',
#    'black ': 'remyrouyer',
#    'result ': '0-1',
#    'whiteelo ': '1609',
#    'blackelo ': '1656',
#    'timecontrol ': '600',
#    'endtime ': '23:31:17 PDT',
#    'termination ': 'remyrouyer won on time',
#    'moves': '1. d4 e5 2. dxe5 Bc5 3. Nf3 d5 4. exd6 Ne7 5. e3 Bxd6 6. Bc4 Bg4 7. Nbd2 Nbc6 8.\n\n',
#    'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.16"]\n\n[Round "-"]\n\n[White "piyushdhb"]\n\n[Black "remyrouyer"]\n\n[Result "0-1"]\n\n[WhiteElo "1609"]\n\n[BlackElo "1656"]\n\n[TimeControl "600"]\n\n[EndTime "23:31:17 PDT"]\n\n[Termination "remyrouyer won on time"]\n\n\n\n1. d4 e5 2. dxe5 Bc5 3. Nf3 d5 4. exd6 Ne7 5. e3 Bxd6 6. Bc4 Bg4 7. Nbd2 Nbc6 8.\n\nc3 Ne5 9. Be2 Qd7 10. Nxe5 Bxe2 11. Qxe2 Bxe5 12. Nf3 Bf6 13. O-O O-O-O 14. Bd2\n\ng5 15. Rfd1 g4 16. Nd4 h5 17. Be1 Bxd4 18. Rxd4 Qe6 19. Rad1 Nc6 20. Rxd8+ Rxd8\n\n21. Rxd8+ Nxd8 22. f3 f5 23. Bh4 Nf7 24. Qd3 Nd6 25. Qd4 Qxa2 26. b4 b6 27. h3\n\ngxh3 28. gxh3 Qa1+ 29. Kg2 Qb2+ 30. Kg1 Qc1+ 31. Kg2 Qc2+ 32. Kg1 Nb5 33. Qd8+\n\nKb7 34. Qd5+ Ka6 35. Qd8 Nxc3 36. Qc8+ Kb5 37. Qd7+ Kc4 38. Qd4+ Kb3 0-1\n\n\n\n[Event "Live Chess"]\n\n'},
#   {'event ': 'Live Chess',
#    'site ': 'Chess.com',
#    'date ': '2021.10.16',
#    'round ': '-',
#    'white ': 'elyoui_21',
#    'black ': 'remyrouyer',
#    'result ': '0-1',
#    'whiteelo ': '1594',
#    'blackelo ': '1663',
#    'timecontrol ': '600',
#    'endtime ': '23:44:18 PDT',
#    'termination ': 'remyrouyer won by checkmate',
#    'moves': '1. e3 e5 2. c3 d5 3. d4 e4 4. a3 f5 5. g3 Nf6 6. h3 Be7 7. b4 Be6 8. Bb2 Nbd7 9.\n\n',
# ...
#  {'event ': 'Live Chess',
#   'site ': 'Chess.com',
#   'date ': '2021.10.17',
#   'round ': '-',
#   'white ': 'remyrouyer',
#   'black ': 'besmerab',
#   'result ': '1-0',
#   'whiteelo ': '1686',
#   'blackelo ': '1676',
#   'timecontrol ': '600',
#   'endtime ': '0:54:19 PDT',
#   'termination ': 'remyrouyer won on time',
#   'moves': '1. e4 c6 2. c3 d5 3. e5 Bf5 4. d4 e6 5. Nf3 Nd7 6. Bd3 Ne7 7. Bxf5 Nxf5 8. Bg5\n\n',
#   'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.17"]\n\n[Round "-"]\n\n[White "remyrouyer"]\n\n[Black "besmerab"]\n\n[Result "1-0"]\n\n[WhiteElo "1686"]\n\n[BlackElo "1676"]\n\n[TimeControl "600"]\n\n[EndTime "0:54:19 PDT"]\n\n[Termination "remyrouyer won on time"]\n\n\n\n1. e4 c6 2. c3 d5 3. e5 Bf5 4. d4 e6 5. Nf3 Nd7 6. Bd3 Ne7 7. Bxf5 Nxf5 8. Bg5\n\nBe7 9. Bxe7 Qxe7 10. O-O O-O 11. Nbd2 c5 12. b3 Rac8 13. a4 b6 14. a5 b5 15. a6\n\nNb6 16. Qe2 cxd4 17. cxd4 Rc2 18. Qd3 Rfc8 19. g4 Nh4 20. Nxh4 Qxh4 21. f3 R8c3\n\n22. Qe2 Qg5 23. Rfd1 Re3 24. Qxb5 h5 25. h3 Qf4 26. Qf1 Qxd4 27. Qf2 Qxe5 28.\n\nRe1 d4 29. Rad1 Nd5 30. Nc4 Rxe1+ 31. Rxe1 Rxf2 32. Nxe5 Rb2 33. Ra1 hxg4 34.\n\nhxg4 Rxb3 35. Nc6 Rxf3 36. Nxa7 d3 37. Nc6 d2 38. a7 Nb6 39. Kg2 Rc3 40. Rb1\n\nRxc6 41. Rxb6 d1=Q 42. a8=Q+ Kh7 43. Qxc6 Qxg4+ 44. Kf2 Qf4+ 45. Qf3 Qxf3+ 46.\n\nKxf3 g5 47. Rb7 Kg6 48. Kg4 f5+ 49. Kg3 Kf6 50. Rb6 Kg6 51. Rxe6+ Kf7 52. Rb6\n\nKe7 53. Rg6 Kf7 54. Rxg5 Ke6 55. Rg6+ Ke5 56. Rg8 Ke6 57. Re8+ Kf6 58. Rf8+ Ke6\n\n59. Kf4 Ke7 60. Rxf5 Kd6 61. Ke4 Ke6 62. Rh5 Kd6 63. Kd4 Ke6 64. Ra5 Kd6 65.\n\nRa6+ Kc7 66. Kc5 Kb7 67. Rh6 Kc7 68. Rh7+ Kd8 69. Kd6 Ke8 70. Ra7 Kf8 71. Ke6\n\nKg8 72. Kf6 Kh8 73. Kg6 1-0\n\n\n\n[Event "Live Chess"]\n\n'},
#  {'event ': 'Live Chess',
#   'site ': 'Chess.com',
#   'date ': '2021.10.17',
#   'round ': '-',
#   'white ': 'remyrouyer',
#   'black ': 'Cent1991',
#   'result ': '1-0',
#   'whiteelo ': '1693',
#   'blackelo ': '1656',
#   'timecontrol ': '600',
#   'endtime ': '1:07:21 PDT',
#   'termination ': 'remyrouyer won by resignation',
#   'moves': '1. e4 c5 2. c3 d6 3. d4 cxd4 4. cxd4 e6 5. Nc3 Be7 6. Nf3 Nf6 7. e5 dxe5 8. dxe5\n\n',
#   'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.17"]\n\n[Round "-"]\n\n[White "remyrouyer"]\n\n[Black "Cent1991"]\n\n[Result "1-0"]\n\n[WhiteElo "1693"]\n\n[BlackElo "1656"]\n\n[TimeControl "600"]\n\n[EndTime "1:07:21 PDT"]\n\n[Termination "remyrouyer won by resignation"]\n\n\n\n1. e4 c5 2. c3 d6 3. d4 cxd4 4. cxd4 e6 5. Nc3 Be7 6. Nf3 Nf6 7. e5 dxe5 8. dxe5\n\nNfd7 9. Bb5 O-O 10. O-O Nc6 11. Bf4 a6 12. Bxc6 bxc6 13. Qc2 Qc7 14. Rad1 Rd8\n\n15. Bg5 f6 16. exf6 Nxf6 17. Ne4 Nxe4 18. Bxe7 Qxe7 19. Rxd8+ Qxd8 20. Qxe4 Bb7\n\n21. Qxe6+ Kh8 22. Ne5 Qc7 23. Nf7+ Kg8 24. Nh6+ Kh8 25. Nf7+ Kg8 26. Nd6+ Kf8\n\n27. Re1 g6 28. Qf6+ Kg8 29. Nxb7 Qf7 30. Qxf7+ Kxf7 31. Nc5 a5 32. Re6 Rd8 33.\n\nKf1 Rd2 34. Rxc6 Rxb2 35. Rc7+ Kg8 36. a4 Rb6 37. Ra7 Rb1+ 38. Ke2 Ra1 39. Rxa5\n\nRa2+ 40. Kf3 Ra3+ 41. Ke4 Kf7 42. Ra7+ Kg8 43. a5 Rc3 44. Nd3 Ra3 45. a6 Ra4+\n\n46. Ke3 Ra5 47. Ra8+ Kf7 48. a7 Ke7 49. Nb4 h5 50. Nc6+ 1-0\n\n\n\n[Event "Live Chess"]\n\n'},
#  {'event ': 'Live Chess',
#   'site ': 'Chess.com',
#   'date ': '2021.10.17',
#   'round ': '-',
#   'white ': 'md812',
#   'black ': 'remyrouyer',
#   'result ': '1-0',
#   'whiteelo ': '1634',
#   'blackelo ': '1683',
#   'timecontrol ': '600',
#   'endtime ': '1:18:39 PDT',
#   'termination ': 'md812 won by resignation',
#   'moves': '1. d4 e5 2. dxe5 Bc5 3. Nf3 d5 4. exd6 Ne7 5. e3 Bxd6 6. Be2 Nbc6 7. O-O Bg4 8.\n\n',
#   'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.17"]\n\n[Round "-"]\n\n[White "md812"]\n\n[Black "remyrouyer"]\n\n[Result "1-0"]\n\n[WhiteElo "1634"]\n\n[BlackElo "1683"]\n\n[TimeControl "600"]\n\n[EndTime "1:18:39 PDT"]\n\n[Termination "md812 won by resignation"]\n\n\n\n1. d4 e5 2. dxe5 Bc5 3. Nf3 d5 4. exd6 Ne7 5. e3 Bxd6 6. Be2 Nbc6 7. O-O Bg4 8.\n\nh3 Bxf3 9. Bxf3 Qd7 10. c4 O-O-O 11. Qa4 a6 12. Nc3 f5 13. Nd5 g5 14. Nxe7+ Nxe7\n\n15. Qxd7+ Rxd7 16. b4 Kb8 17. Bb2 g4 18. Bxb7 Rhd8 19. Bxa6 gxh3 20. c5 Rg8 21.\n\ncxd6 Rxg2+ 22. Kh1 Nd5 23. dxc7+ Nxc7 24. Bc4 Rd2 25. Be5 Kb7 26. Bxc7 Kxc7 27.\n\na4 h2 28. Kxg2 h5 29. Kxh2 h4 30. a5 Rc2 31. Bd5 Rb2 32. a6 Rxb4 33. a7 1-0\n\n\n\n[Event "Live Chess"]\n\n'},
#  {'event ': 'Live Chess',
#   'site ': 'Chess.com',
#   'date ': '2021.10.17',
#   'round ': '-',
#   'white ': 'imfromkerala',
#   'black ': 'remyrouyer',
#   'result ': '1-0',
#   'whiteelo ': '1595',
#   'blackelo ': '1673',
#   'timecontrol ': '600',
#   'endtime ': '1:29:04 PDT',
#   'termination ': 'imfromkerala won by resignation',
#   'moves': '1. e4 e5 2. Nf3 Nf6 3. Nxe5 d6 4. Nd3 Nxe4 5. Qe2 Qe7 6. f3 Nc5 7. Nxc5 dxc5 8.\n\n',
#   'pgn': '[Site "Chess.com"]\n\n[Date "2021.10.17"]\n\n[Round "-"]\n\n[White "imfromkerala"]\n\n[Black "remyrouyer"]\n\n[Result "1-0"]\n\n[WhiteElo "1595"]\n\n[BlackElo "1673"]\n\n[TimeControl "600"]\n\n[EndTime "1:29:04 PDT"]\n\n[Termination "imfromkerala won by resignation"]\n\n\n\n1. e4 e5 2. Nf3 Nf6 3. Nxe5 d6 4. Nd3 Nxe4 5. Qe2 Qe7 6. f3 Nc5 7. Nxc5 dxc5 8.\n\nNc3 Nc6 9. Nd5 Qxe2+ 10. Bxe2 Bd6 11. Bb5 Bd7 12. O-O O-O-O 13. a4 a6 14. Bxc6\n\nBxc6 15. Nc3 c4 16. Ne4 Bxe4 17. fxe4 f6 18. b3 Be5 19. Rb1 cxb3 20. cxb3 g5 21.\n\nBb2 Bxb2 22. Rxb2 h5 23. Rxf6 g4 24. g3 h4 25. Kg2 hxg3 26. Kxg3 Rdg8 27. Rc2\n\nRh3+ 28. Kg2 g3 29. Kxh3 g2 30. Rf8+ Rxf8 31. Kxg2 Kd7 32. d3 Kd6 33. Kg3 c6 34.\n\nh4 Ke5 35. Rc4 Rg8+ 36. Kf3 Rh8 37. Kg4 Rh7 38. h5 Kf6 39. Rc5 Ke6 40. Kg5 Kd6\n\n41. d4 b6 42. Rf5 c5 43. Kg6 Rh8 44. Kg7 Rc8 45. dxc5+ bxc5 46. h6 Rc7+ 47. Rf7\n\nRc8 48. h7 Ke5 49. Re7+ Kd4 50. h8=Q Rxh8 51. Kxh8 Kc3 52. e5 Kxb3 53. Re6 c4\n\n54. Rxa6 c3 55. e6 Kb2 56. e7 c2 57. Rc6 1-0\n\n'},
#  {'event ': 'Urusov Gambit: Chapter 1',
#   'site ': 'https://lichess.org/study/bUmK3HRF/Xh4mmWR8',
#   'result ': '*',
#   'utcdate ': '2020.11.21',
#   'utctime ': '13:57:40',
#   'variant ': 'Standard',
#   'eco ': 'C43',
#   'opening ': "Bishop's Opening: Urusov Gambit, Keidansky Gambit",
#   'annotator ': 'https://lichess.org/@/remyrouyer',
#   'moves': '1. e4 e5 2. Bc4 Nf6 3. d4 exd4 { [%csl Gf8] } (3... Nxe4 4. dxe5 { [%csl Gf3] } 4... d5 (4... Bc5 5. Qd5 Qh4 (5... Bxf2+ 6. Kf1 O-O 7. Qxe4 Bb6 (7... d5 8. Qxd5 Qh4 9. Nf3 Be6) 8. Nc3 c6 9. Bd3 g6 10. Nf3 d5 11. exd6) 6. g3 Bxf2+ 7. Kf1 Bxg3 8. Nc3 O-O 9. Nxe4 c6 10. hxg3 Qxh1 (10... cxd5 11. Rxh4 dxc4) 11. Nf6+ gxf6 12. Qxh1) (4... Nc5 5. Be3 (5. Qd5) 5... Nc6 6. Qe2 (6. Bxc5)) (4... Ng5 5. f4 Ne6) (4... Qh4 5. Be3) (4... Qe7 5. Qe2 Qxe5 (5... Nc5) 6. f3 d5 7. Bb3 Nc6) (4... Nc6 5. Bxf7+ Kxf7 6. Qd5+ Ke8 7. Qxe4 Qe7 8. Nf3 Qb4+ 9. Nc3 Qxe4+) (4... Nxf2 5. Qf3 Qe7 { [%csl Ge7,Gd5] } 6. Qxf2) 5. Bxd5 Nc5 (5... Nxf2 { [%cal Gd1f3] } 6. Qf3 Bb4+ 7. Kxf2 O-O 8. Nc3 Be6 9. Bxb7 Nd7 10. Bxa8 Nxe5 11. Qe4) 6. Bxf7+ Ke7 (6... Kxf7 7. Qxd8) 7. Bg5+ Kxf7 8. Qxd8) (3... Nc6 4. d5 Na5 (4... Ne7) 5. Bd3 b6 (5... Bc5 6. a3 Bb6 7. b4)) (3... d5 4. dxe5 Bb4+ 5. c3 Bc5 6. exd5 Ng4 (6... Bg4) 7. Qe2 Bxf2+ 8. Kf1 Bxg1 9. Kxg1 Qe7) (3... d6 4. dxe5 dxe5 5. Qxd8+ Kxd8 6. Nf3 Nc6 (6... Nxe4 7. Nxe5 Be6 (7... Nd6 8. Nxf7+ Nxf7 9. Bxf7) 8. Bxe6 fxe6 9. Nf7+) (6... Bd6 7. Ng5 Ke7 8. Nxf7 Rf8 9. Nxd6 cxd6) 7. Bxf7 { [%cal Gf8d6,Gf6e4,Gc8g4,Gf8c5,Gc5b4] } 7... Nxe4 8. Bd5 Bf5 9. Bxc6 bxc6 10. Nxe5 Bc5 11. Nxc6+ Kd7 12. Ne5+ Kc8 13. Be3 Rb8 14. b3 Bxe3 15. fxe3 Rb5 16. Nd3) (3... Bd6 4. dxe5 Bxe5 5. f4 Bd6 (5... Nxe4 6. Qd5 Qh4+ (6... O-O 7. fxe5 c6 (7... Qh4+ 8. g3 Nxg3 9. hxg3 Qxg3+ 10. Kf1)) 7. g3 Qe7 8. fxe5 Nf6 9. Qxf7+ Qxf7 10. Bxf7+ Kxf7 11. exf6 Re8+ 12. Ne2) 6. e5 Bb4+ (6... Qe7 7. Qe2 O-O 8. exf6 Qxf6 9. Nc3 Bxf4 10. Bxf4 Qxf4 11. Nd5 { [%csl Gd5] }) 7. c3 Bc5 8. exf6) (3... Bb4+ 4. c3 Bd6 (4... d5 5. dxe5 dxc4 (5... Bc5 6. exd5 Ng4 7. Qe2 Bxf2+ (7... O-O 8. Nf3 Bxf2+ 9. Kf1 Bc5 10. h3 Nxe5 11. Qxe5 Nd7) 8. Kf1 Bxg1 9. Kxg1 Qe7 10. Bf4 g5 11. Be3 Nxe5) 6. Qxd8+ Kxd8 7. exf6 Bf8 8. Bg5 g6) (4... Ba5 5. dxe5 Nxe4 6. Qd5 Qh4 7. g3 Qh5 8. Qxe4) 5. dxe5 Bxe5 6. f4 Bd6 7. e5 Bc5 8. exf6 O-O (8... Qxf6 9. Qe2+ Kd8 10. Qh5) 9. Qd5 d6 10. Qg5 g6 11. Ne2 Nd7 12. f5 Qxf6 13. fxg6 hxg6 14. Qxf6 Nxf6) (3... Qe7) 4. Nf3 Nxe4 (4... d5 5. exd5 Nxd5 (5... Bb4+ 6. Nbd2 Nxd5 7. O-O O-O 8. Nb3) 6. O-O (6. Qxd4 Be6 7. O-O Nc6 8. Qe4) 6... Be7 7. Qxd4 Nf6 8. Qxd8+ Bxd8 9. Re1+ Be7 10. Nc3 Nc6 11. Nb5 O-O 12. Nxc7 Rb8) (4... Nc6 { [%cal Ge4e5] } 5. e5 { [%csl Gd5] } 5... d5 { [%csl Gb5][%cal Gc4b5] } (5... Ng4 { [%cal Gf3d4] } 6. O-O Be7 7. Re1 d6 8. exd6 cxd6 (8... Qxd6 9. b3) 9. Bg5 Nge5 10. Bxe7 Qxe7 11. Be2) (5... Ne4 { [%csl Ge2][%cal Gd1e2] }) 6. Bb5 { [%csl Gd7][%cal Gf6e4,Gf6d7] } 6... Ne4 { [%cal Gf3d4] } 7. Nxd4 Bc5 (7... Bd7 8. Bxc6 bxc6 (8... Bxc6 9. O-O Bc5 10. Nxc6 bxc6 11. Nd2 O-O 12. Nxe4 dxe4 13. Bf4) 9. O-O Bc5 10. f3 Ng5 11. f4 (11. Be3 O-O 12. f4 Ne4 (12... Ne6 13. c3 Qe7 14. Nd2) 13. Nd2 Nxd2 14. Qxd2 Bb6 15. Nf3) 11... Ne6 (11... Ne4 12. Be3 Qb8 { Stockfish 13+NNUE\n\n',
#   'pgn': '[Event "Urusov Gambit: Chapter 1"]\n\n[Site "https://lichess.org/study/bUmK3HRF/Xh4mmWR8"]\n\n[Result "*"]\n\n[UTCDate "2020.11.21"]\n\n[UTCTime "13:57:40"]\n\n[Variant "Standard"]\n\n[ECO "C43"]\n\n[Opening "Bishop\'s Opening: Urusov Gambit, Keidansky Gambit"]\n\n[Annotator "https://lichess.org/@/remyrouyer"]\n\n\n\n1. e4 e5 2. Bc4 Nf6 3. d4 exd4 { [%csl Gf8] } (3... Nxe4 4. dxe5 { [%csl Gf3] } 4... d5 (4... Bc5 5. Qd5 Qh4 (5... Bxf2+ 6. Kf1 O-O 7. Qxe4 Bb6 (7... d5 8. Qxd5 Qh4 9. Nf3 Be6) 8. Nc3 c6 9. Bd3 g6 10. Nf3 d5 11. exd6) 6. g3 Bxf2+ 7. Kf1 Bxg3 8. Nc3 O-O 9. Nxe4 c6 10. hxg3 Qxh1 (10... cxd5 11. Rxh4 dxc4) 11. Nf6+ gxf6 12. Qxh1) (4... Nc5 5. Be3 (5. Qd5) 5... Nc6 6. Qe2 (6. Bxc5)) (4... Ng5 5. f4 Ne6) (4... Qh4 5. Be3) (4... Qe7 5. Qe2 Qxe5 (5... Nc5) 6. f3 d5 7. Bb3 Nc6) (4... Nc6 5. Bxf7+ Kxf7 6. Qd5+ Ke8 7. Qxe4 Qe7 8. Nf3 Qb4+ 9. Nc3 Qxe4+) (4... Nxf2 5. Qf3 Qe7 { [%csl Ge7,Gd5] } 6. Qxf2) 5. Bxd5 Nc5 (5... Nxf2 { [%cal Gd1f3] } 6. Qf3 Bb4+ 7. Kxf2 O-O 8. Nc3 Be6 9. Bxb7 Nd7 10. Bxa8 Nxe5 11. Qe4) 6. Bxf7+ Ke7 (6... Kxf7 7. Qxd8) 7. Bg5+ Kxf7 8. Qxd8) (3... Nc6 4. d5 Na5 (4... Ne7) 5. Bd3 b6 (5... Bc5 6. a3 Bb6 7. b4)) (3... d5 4. dxe5 Bb4+ 5. c3 Bc5 6. exd5 Ng4 (6... Bg4) 7. Qe2 Bxf2+ 8. Kf1 Bxg1 9. Kxg1 Qe7) (3... d6 4. dxe5 dxe5 5. Qxd8+ Kxd8 6. Nf3 Nc6 (6... Nxe4 7. Nxe5 Be6 (7... Nd6 8. Nxf7+ Nxf7 9. Bxf7) 8. Bxe6 fxe6 9. Nf7+) (6... Bd6 7. Ng5 Ke7 8. Nxf7 Rf8 9. Nxd6 cxd6) 7. Bxf7 { [%cal Gf8d6,Gf6e4,Gc8g4,Gf8c5,Gc5b4] } 7... Nxe4 8. Bd5 Bf5 9. Bxc6 bxc6 10. Nxe5 Bc5 11. Nxc6+ Kd7 12. Ne5+ Kc8 13. Be3 Rb8 14. b3 Bxe3 15. fxe3 Rb5 16. Nd3) (3... Bd6 4. dxe5 Bxe5 5. f4 Bd6 (5... Nxe4 6. Qd5 Qh4+ (6... O-O 7. fxe5 c6 (7... Qh4+ 8. g3 Nxg3 9. hxg3 Qxg3+ 10. Kf1)) 7. g3 Qe7 8. fxe5 Nf6 9. Qxf7+ Qxf7 10. Bxf7+ Kxf7 11. exf6 Re8+ 12. Ne2) 6. e5 Bb4+ (6... Qe7 7. Qe2 O-O 8. exf6 Qxf6 9. Nc3 Bxf4 10. Bxf4 Qxf4 11. Nd5 { [%csl Gd5] }) 7. c3 Bc5 8. exf6) (3... Bb4+ 4. c3 Bd6 (4... d5 5. dxe5 dxc4 (5... Bc5 6. exd5 Ng4 7. Qe2 Bxf2+ (7... O-O 8. Nf3 Bxf2+ 9. Kf1 Bc5 10. h3 Nxe5 11. Qxe5 Nd7) 8. Kf1 Bxg1 9. Kxg1 Qe7 10. Bf4 g5 11. Be3 Nxe5) 6. Qxd8+ Kxd8 7. exf6 Bf8 8. Bg5 g6) (4... Ba5 5. dxe5 Nxe4 6. Qd5 Qh4 7. g3 Qh5 8. Qxe4) 5. dxe5 Bxe5 6. f4 Bd6 7. e5 Bc5 8. exf6 O-O (8... Qxf6 9. Qe2+ Kd8 10. Qh5) 9. Qd5 d6 10. Qg5 g6 11. Ne2 Nd7 12. f5 Qxf6 13. fxg6 hxg6 14. Qxf6 Nxf6) (3... Qe7) 4. Nf3 Nxe4 (4... d5 5. exd5 Nxd5 (5... Bb4+ 6. Nbd2 Nxd5 7. O-O O-O 8. Nb3) 6. O-O (6. Qxd4 Be6 7. O-O Nc6 8. Qe4) 6... Be7 7. Qxd4 Nf6 8. Qxd8+ Bxd8 9. Re1+ Be7 10. Nc3 Nc6 11. Nb5 O-O 12. Nxc7 Rb8) (4... Nc6 { [%cal Ge4e5] } 5. e5 { [%csl Gd5] } 5... d5 { [%csl Gb5][%cal Gc4b5] } (5... Ng4 { [%cal Gf3d4] } 6. O-O Be7 7. Re1 d6 8. exd6 cxd6 (8... Qxd6 9. b3) 9. Bg5 Nge5 10. Bxe7 Qxe7 11. Be2) (5... Ne4 { [%csl Ge2][%cal Gd1e2] }) 6. Bb5 { [%csl Gd7][%cal Gf6e4,Gf6d7] } 6... Ne4 { [%cal Gf3d4] } 7. Nxd4 Bc5 (7... Bd7 8. Bxc6 bxc6 (8... Bxc6 9. O-O Bc5 10. Nxc6 bxc6 11. Nd2 O-O 12. Nxe4 dxe4 13. Bf4) 9. O-O Bc5 10. f3 Ng5 11. f4 (11. Be3 O-O 12. f4 Ne4 (12... Ne6 13. c3 Qe7 14. Nd2) 13. Nd2 Nxd2 14. Qxd2 Bb6 15. Nf3) 11... Ne6 (11... Ne4 12. Be3 Qb8 { Stockfish 13+NNUE\n\nDepth 54\n\n0.0 13. b3 Bb6 14. Nd2 c5 15. e6 O-O 16. Nf5 Bxe6 17. Ne7+ Kh8 18. Nxe4 dxe4\n\n0.0 13. Qd3 Qxb2 14. Nd2 Nxd2 15. Qxd2 O-O 16. a3 Qb7 17. h3 Rfe8 18. Nb3 Bxe3+\n\n0.0 13. Nd2 Qxb2 14. Nxe4 dxe4 15. Qd2 Qb4 16. Qf2 Qc3 17. Rfe1 Bb6 18. a4 a5\n\n0.0 13. Nc3 Qxb2 14. Nxe4 dxe4 15. Qd2 Qb4 16. Qf2 Qc3 17. } { [%cal Gd1d3,Gb2b3,Gb1c3,Gb1d2,Gd1c1] } (12... O-O 13. Nd2) (12... Bb6) 13. b3 (13. Qc1 Qb6 (13... Bxd4 14. Bxd4 c5 15. Bf2 Bb5 16. Rd1 Nxf2 17. Kxf2 Bc6 18. Qe3 Qb6 19. Nd2 O-O-O 20. a4) 14. c3 a5) 13... Qb6 (13... O-O 14. Qd3 Qb6 15. c3 Bxd4 16. cxd4 Bf5 17. Re1 Qb4 18. Nd2 a5 19. Nxe4 Bxe4 20. Qd2) (13... Bb6 14. c4 Qb7 15. Nd2 c5 16. Ne2 Nxd2 17. Qxd2 dxc4 18. bxc4) 14. Qd3 Bxd4 15. Bxd4 c5 16. Bf2 Bb5) 12. c3 g6 { [%csl Ge3][%cal Gc1e3,Gh2h3] } (12... f5) 13. h3) 8. Be3 Bd7 9. Bxc6 bxc6 (9... Bxc6) 10. Nd2 Nxd2 11. Qxd2) (4... d6 5. Qxd4 Be7  ...
#  {'event ': 'Urusov Gambit: eric rosen',
#   'site ': 'https://lichess.org/study/bUmK3HRF/pW4LF2xK',
#   'result ': '*',
#   'utcdate ': '2021.03.28',
#   'utctime ': '21:57:10',
#   'variant ': 'Standard',
#   'eco ': 'C44',
#   'opening ': 'Scotch Game: Scotch Gambit, Advance Variation',
#   'annotator ': 'https://lichess.org/@/remyrouyer',
#   'moves': '1. e4 e5 2. Bc4 Nf6 3. d4 exd4 4. Nf3 Nc6 5. e5 d5 6. Bb5 Ne4 7. Nxd4 Bd7 8. Bxc6 bxc6 (8... Bxc6) 9. O-O Bc5 10. f3 Ng5 11. f4 Ne4 (11... Ne6 12. c3 Bb6 (12... O-O 13. f5 Nxd4 14. cxd4 Bb6 15. a4 (15. Be3 Qh4 16. Nc3)) 13. f5 Nxd4 (13... Ng5 14. Qg4 h6 15. h4) 14. cxd4 Qh4 15. Rf4 Qe7 16. a4 a5 17. Kh1 g6 (17... c5 18. Nc3 c6 19. f6 gxf6 20. exf6 Qe6 21. dxc5 Bc7 22. Rf3 Kd8 23. Be3)) 12. Be3 (12. Kh1) 12... O-O (12... Qb8 13. b3 Qb6 14. Qd3 Bxd4 15. Bxd4 c5 16. Bf2 Bf5 (16... Bb5 17. c4) 17. Qxd5 O-O (17... Rd8 18. Qc4) 18. Qd3) 13. Nd2 Nxd2 14. Qxd2 Bb6 { [%cal Gd4b3,Gc2c3,Gd4f3,Gb6g1] } *\n\n',
#   'pgn': '[Site "https://lichess.org/study/bUmK3HRF/pW4LF2xK"]\n\n[Result "*"]\n\n[UTCDate "2021.03.28"]\n\n[UTCTime "21:57:10"]\n\n[Variant "Standard"]\n\n[ECO "C44"]\n\n[Opening "Scotch Game: Scotch Gambit, Advance Variation"]\n\n[Annotator "https://lichess.org/@/remyrouyer"]\n\n\n\n1. e4 e5 2. Bc4 Nf6 3. d4 exd4 4. Nf3 Nc6 5. e5 d5 6. Bb5 Ne4 7. Nxd4 Bd7 8. Bxc6 bxc6 (8... Bxc6) 9. O-O Bc5 10. f3 Ng5 11. f4 Ne4 (11... Ne6 12. c3 Bb6 (12... O-O 13. f5 Nxd4 14. cxd4 Bb6 15. a4 (15. Be3 Qh4 16. Nc3)) 13. f5 Nxd4 (13... Ng5 14. Qg4 h6 15. h4) 14. cxd4 Qh4 15. Rf4 Qe7 16. a4 a5 17. Kh1 g6 (17... c5 18. Nc3 c6 19. f6 gxf6 20. exf6 Qe6 21. dxc5 Bc7 22. Rf3 Kd8 23. Be3)) 12. Be3 (12. Kh1) 12... O-O (12... Qb8 13. b3 Qb6 14. Qd3 Bxd4 15. Bxd4 c5 16. Bf2 Bf5 (16... Bb5 17. c4) 17. Qxd5 O-O (17... Rd8 18. Qc4) 18. Qd3) 13. Nd2 Nxd2 14. Qxd2 Bb6 { [%cal Gd4b3,Gc2c3,Gd4f3,Gb6g1] } *\n\n\n\n\n\n[Event "Urusov Gambit: Chapter 3"]\n\n'},
#  {'event ': 'Urusov Gambit: Chapter 3',
#   'site ': 'https://lichess.org/study/bUmK3HRF/jTrTUFW4',
#   'result ': '*',
#   'utcdate ': '2022.01.14',
#   'utctime ': '03:01:40',
#   'variant ': 'Standard',
#   'eco ': 'C55',
#   'opening ': 'Italian Game: Two Knights Defense, Open Variation',
#   'annotator ': 'https://lichess.org/@/remyrouyer',
#   'moves': '1. e4 e5 2. Bc4 Nf6 3. d4 Nc6 4. Nf3 Bb4+ 5. c3 Ba5 6. dxe5 *\n\n',
#   'pgn': '[Site "https://lichess.org/study/bUmK3HRF/jTrTUFW4"]\n\n[Result "*"]\n\n[UTCDate "2022.01.14"]\n\n[UTCTime "03:01:40"]\n\n[Variant "Standard"]\n\n[ECO "C55"]\n\n[Opening "Italian Game: Two Knights Defense, Open Variation"]\n\n[Annotator "https://lichess.org/@/remyrouyer"]\n\n\n\n1. e4 e5 2. Bc4 Nf6 3. d4 Nc6 4. Nf3 Bb4+ 5. c3 Ba5 6. dxe5 *\n\n\n\n\n\n'}]

# %%
n == None
# Out:
# False
